# %%
import pandas as pd
import json

# %%
df_b = pd.read_json('yelp_academic_dataset_business.json', lines=True)
drop_columns = ['latitude','longitude','postal_code','state','address','name']
df_b = df_b.drop(drop_columns, axis=1)

# %%
df_u = pd.read_json('yelp_academic_dataset_user.json', lines=True)
drop_columns = ['elite','fans','compliment_more','compliment_profile','compliment_cute','compliment_list', 'compliment_plain','compliment_cool', 'compliment_funny', 'compliment_writer','compliment_photos']
df_u = df_u.drop(drop_columns, axis=1)

# %%
df_u
# Out:
#                         user_id       name  review_count        yelping_since  \
# 0        q_QQ5kBBwlCcbL1s4NVK3g       Jane          1220  2005-03-14 20:26:35
# 1        dIIKEfOgo0KqUfGQvGikPg       Gabi          2136  2007-08-10 19:01:51
# 2        D6ErcUnFALnCQN4b1W_TlA      Jason           119  2007-02-07 15:47:53
# 3        JnPIjvC0cmooNDfsa9BmXg        Kat           987  2009-02-09 16:14:29
# 4        37Hc8hr3cw0iHLoPzLK6Ow  Christine           495  2008-03-03 04:57:05
# ...                         ...        ...           ...                  ...
# 2189452  OrXXOTSQG2hLEoZ4sw03Gg    Matthew             1  2018-08-25 23:07:58
# 2189453  pYZ4Dyx5I92u5gDfGiVTpQ       Jeff             3  2013-08-17 23:58:29
# 2189454  DhrXTJRTLhnvI9UI1q63mg      Emily            10  2012-10-14 23:35:51
# 2189455  ka06dBaC9tvKhc7DJ9_7wQ     Duamel             9  2016-03-24 11:54:52
# 2189456  QfkFTrJ_MdM3Onk6przUJw     Amanda             2  2011-09-15 16:55:59
#
#          useful  funny   cool  \
# 0         15038  10030  11291
# 1         21272  10289  18046
# 2           188    128    130
# 3          7234   4722   4035
# 4          1577    727   1124
# ...         ...    ...    ...
# 2189452       0      1      0
# 2189453       0      0      0
# 2189454       3      0      2
# 2189455       4      2      0
# 2189456       0      0      0
#
#                                                    friends  average_stars  \
# 0        xBDpTUbai0DXrvxCe3X16Q, 7GPNBO496aecrjJfW6UWtg...           3.85
# 1        XPzYf9_mwG2eXYP2BAGSTA, 2LooM5dcIk2o01nftYdPIg...           4.09
# 2        GfB6sC4NJQvSI2ewbQrDNA, jhZtzZNNZJOU2YSZ6jPlXQ...           3.76
# 3        HQZPQhKMwRAyS6BCselVWQ, kP2U1s_sjQfHO9grxiyDTA...           3.77
# 4        -Q88pZUcrfN0BLBDp-bkAQ, etPn4Pv1Gc4cRZjRgB_BOw...           3.72
# ...                                                    ...            ...
# 2189452                                               None           1.00
# 2189453                                               None           4.33
# 2189454                                               None           4.20
# 2189455                                               None           3.89
# 2189456                                               None           5.00
#
#          compliment_hot  compliment_note
# 0                  1710             1212
# 1                  1632             1187
# 2                    22                5
# 3                  1180             1120
# 4                   248               77
# ...                 ...              ...
# 2189452               0                0
# 2189453               0                0
# 2189454               0                0
# 2189455               0                0
# 2189456               0                0
#
# [2189457 rows x 11 columns]

# %%
drop_columns = ['useful','funny','cool','average_stars','compliment_hot','compliment_note','name','review_count','yelping_since']
df_u = df_u.drop(drop_columns, axis=1)

# %%
df_u
# Out:
#                         user_id  \
# 0        q_QQ5kBBwlCcbL1s4NVK3g
# 1        dIIKEfOgo0KqUfGQvGikPg
# 2        D6ErcUnFALnCQN4b1W_TlA
# 3        JnPIjvC0cmooNDfsa9BmXg
# 4        37Hc8hr3cw0iHLoPzLK6Ow
# ...                         ...
# 2189452  OrXXOTSQG2hLEoZ4sw03Gg
# 2189453  pYZ4Dyx5I92u5gDfGiVTpQ
# 2189454  DhrXTJRTLhnvI9UI1q63mg
# 2189455  ka06dBaC9tvKhc7DJ9_7wQ
# 2189456  QfkFTrJ_MdM3Onk6przUJw
#
#                                                    friends
# 0        xBDpTUbai0DXrvxCe3X16Q, 7GPNBO496aecrjJfW6UWtg...
# 1        XPzYf9_mwG2eXYP2BAGSTA, 2LooM5dcIk2o01nftYdPIg...
# 2        GfB6sC4NJQvSI2ewbQrDNA, jhZtzZNNZJOU2YSZ6jPlXQ...
# 3        HQZPQhKMwRAyS6BCselVWQ, kP2U1s_sjQfHO9grxiyDTA...
# 4        -Q88pZUcrfN0BLBDp-bkAQ, etPn4Pv1Gc4cRZjRgB_BOw...
# ...                                                    ...
# 2189452                                               None
# 2189453                                               None
# 2189454                                               None
# 2189455                                               None
# 2189456                                               None
#
# [2189457 rows x 2 columns]

# %%
df1 = pd.read_csv('review1.csv')
df1=df1.drop(['text','review_id','funny','cool'], axis=1)

# %%
df2 = pd.read_csv('review2.csv')
df2=df2.drop(['text','review_id','funny','cool'], axis=1)

# %%
df3 = pd.read_csv('review3.csv')
df3=df3.drop(['text','review_id','funny','cool'], axis=1)

# %%
df4 = pd.read_csv('review4.csv')
df4=df4.drop(['text','review_id','funny','cool'], axis=1)

# %%
df5 = pd.read_csv('review5.csv')
df5=df5.drop(['text','review_id','funny','cool'], axis=1)

# %%
df6 = pd.read_csv('review6.csv')
df6=df6.drop(['text','review_id','funny','cool'], axis=1)

# %%
df7 = pd.read_csv('review7.csv')
df7=df7.drop(['text','review_id','funny','cool'], axis=1)

# %%
df8 = pd.read_csv('review8.csv')
df8=df8.drop(['text','review_id','funny','cool'], axis=1)

# %%
df9 = pd.read_csv('review9.csv')
df9=df9.drop(['text','review_id','funny','cool'], axis=1)

# %%
df10 = pd.read_csv('review10.csv')
df10=df10.drop(['text','review_id','funny','cool'], axis=1)

# %%
df11 = pd.read_csv('review11.csv')
df11=df11.drop(['text','review_id','funny','cool'], axis=1)

# %%
df12 = pd.read_csv('review12.csv')
df12=df12.drop(['text','review_id','funny','cool'], axis=1)

# %%
df13 = pd.read_csv('review13.csv')
df13=df13.drop(['text','review_id','funny','cool'], axis=1)

# %%
df14 = pd.read_csv('review14.csv')
df14=df14.drop(['text','review_id','funny','cool'], axis=1)

# %%
df15 = pd.read_csv('review15.csv')
df15=df15.drop(['text','review_id','funny','cool'], axis=1)

# %%
df16 = pd.read_csv('review16.csv')
df16=df16.drop(['text','review_id','funny','cool'], axis=1)

# %%
df17 = pd.read_csv('review17.csv')
df17=df17.drop(['text','review_id','funny','cool'], axis=1)

# %%
df18 = pd.read_csv('review18.csv')
df18=df18.drop(['text','review_id','funny','cool'], axis=1)

# %%
#create a dataframe with all the reviews but without the text which is not relevant for the analysis
frames = [df1, df2, df3,df4, df5, df6,df7, df8, df9,df10, df11, df12,df13, df14, df15,df16, df17, df18]
result = pd.concat(frames)

# %%
import numpy as np
df_Van=df_b[df_b['city']=='Vancouver']
df_Van=df_Van.replace(to_replace='None', value=np.nan)
df_Van=df_Van[~df_Van['categories'].isnull()]
df_Van=df_Van[df_Van['categories'].str.contains('Restaurants')]
df_Van
# Out:
#                    business_id       city  stars  review_count  is_open  \
# 5       D4JtQNTI4X3KcbzacDJsMw  Vancouver    3.5           169        1
# 74      Mf9io8WkMyGautXuSSfGTg  Vancouver    3.5            63        1
# 131     jfDfHzAq6iKkRnzzZ4n1nQ  Vancouver    4.5            31        0
# 138     JeU01XydOJZBWAnlqHwP7w  Vancouver    3.0             9        0
# 143     OfA_4cHgvlknHMcn0qNs2w  Vancouver    1.0             9        1
# ...                        ...        ...    ...           ...      ...
# 160424  WtoWJAOmLbordZcE-yY_SQ  Vancouver    3.0            30        1
# 160437  fWsrhRBZooqGfKwO9QT9ng  Vancouver    3.0            78        0
# 160469  ZE2KU6QYcicqn0oO8YhZUQ  Vancouver    2.0             5        0
# 160523  dplKdpONowTjlPZvq0wSRw  Vancouver    4.0            53        1
# 160551  1CHPSnEh4axD10HCqe8k-A  Vancouver    3.5             7        0
#
#                                                attributes  \
# 5       {'GoodForKids': 'True', 'Alcohol': 'u'none'', ...
# 74      {'WiFi': 'u'free'', 'Corkage': 'True', 'Restau...
# 131     {'RestaurantsAttire': 'u'casual'', 'HasTV': 'F...
# 138     {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 143     {'GoodForKids': 'True', 'RestaurantsReservatio...
# ...                                                   ...
# 160424  {'BusinessParking': '{'garage': False, 'street...
# 160437  {'Alcohol': 'u'beer_and_wine'', 'Ambience': '{...
# 160469  {'WiFi': 'u'paid'', 'RestaurantsTakeOut': 'Tru...
# 160523  {'RestaurantsPriceRange2': '1', 'GoodForMeal':...
# 160551  {'RestaurantsDelivery': 'False', 'RestaurantsG...
#
#                                                categories  \
# 5                                       Restaurants, Thai
# 74      Restaurants, Food Delivery Services, Mexican, ...
# 131     Restaurants, Canadian (New), Sushi Bars, Ameri...
# 138                                   Indian, Restaurants
# 143                                    Restaurants, Pizza
# ...                                                   ...
# 160424                                 Pizza, Restaurants
# 160437  Modern European, Gluten-Free, Restaurants, Bre...
# 160469                               Italian, Restaurants
# 160523  Coffee Roasteries, Breakfast & Brunch, Food, C...
# 160551                               Chinese, Restaurants
#
#                                                     hours
# 5       {'Monday': '17:0-21:0', 'Tuesday': '17:0-21:0'...
# 74      {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 131     {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 138                                                  None
# 143     {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# ...                                                   ...
# 160424  {'Monday': '11:0-1:0', 'Tuesday': '11:0-1:0', ...
# 160437  {'Monday': '8:0-15:0', 'Tuesday': '8:0-15:0', ...
# 160469  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...
# 160523  {'Monday': '7:0-18:0', 'Tuesday': '7:0-18:0', ...
# 160551                                               None
#
# [5026 rows x 8 columns]

# %%
a=df_b.groupby('city').count().sort_values('business_id')

# %%
result=result.drop(['useful','date'], axis=1)

# %%
data=pd.merge(result,df_Van)
# Out:
# /Applications/anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:1151: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(

# %%
data=data.drop(['attributes','categories','hours','is_open','review_count','city'],axis=1)
data
# Out:
#                       user_id             business_id  stars
# 0      tLwr8JoGxjRNNoSenPk1ew  DSAx-FBLT0FcGC_aW_C8rA      4
# 1      N5bTFlG1cs1eBSTwpNKHHg  DSAx-FBLT0FcGC_aW_C8rA      4
# 2      T3p2sDKZlWNSFC6-axt_XA  DSAx-FBLT0FcGC_aW_C8rA      4
# 3      HqgLHcpN3q7iNLce-oEnvg  DSAx-FBLT0FcGC_aW_C8rA      4
# 4      K7Eb8-QWfeKX3tLcVngDpA  DSAx-FBLT0FcGC_aW_C8rA      4
# ...                       ...                     ...    ...
# 61251  RSIxPMozpdNRbWujqarZiQ  piwUR6Ucov53hQ2aT9PveQ      2
# 61252  9LVjFd_NpaFZ-DFO1T3RlQ  znb9XlraxrdeK3h0OAMHfA      4
# 61253  LXfKtlVWB1Eiww8-XW_2GQ  tY8u7jr_w20S_jwgdFpXAQ      4
# 61254  bG-mZN_Ph67PYkcqI1bKwg  vURN2ZZgoccUHScFpWgKsA      3
# 61255  iNIxjH-qoi0DW-0M2ML2DA  DsNNLmJIgYq_8kiLYvmhhg      4
#
# [61256 rows x 3 columns]

# %%
data1=data
data1.rename(columns={'user_id':'user_id1'},inplace=True)

# %%
data1.rename(columns={'stars':'stars1'},inplace=True)
data1
# Out:
#                      user_id1             business_id  stars1
# 0      tLwr8JoGxjRNNoSenPk1ew  DSAx-FBLT0FcGC_aW_C8rA       4
# 1      N5bTFlG1cs1eBSTwpNKHHg  DSAx-FBLT0FcGC_aW_C8rA       4
# 2      T3p2sDKZlWNSFC6-axt_XA  DSAx-FBLT0FcGC_aW_C8rA       4
# 3      HqgLHcpN3q7iNLce-oEnvg  DSAx-FBLT0FcGC_aW_C8rA       4
# 4      K7Eb8-QWfeKX3tLcVngDpA  DSAx-FBLT0FcGC_aW_C8rA       4
# ...                       ...                     ...     ...
# 61251  RSIxPMozpdNRbWujqarZiQ  piwUR6Ucov53hQ2aT9PveQ       2
# 61252  9LVjFd_NpaFZ-DFO1T3RlQ  znb9XlraxrdeK3h0OAMHfA       4
# 61253  LXfKtlVWB1Eiww8-XW_2GQ  tY8u7jr_w20S_jwgdFpXAQ       4
# 61254  bG-mZN_Ph67PYkcqI1bKwg  vURN2ZZgoccUHScFpWgKsA       3
# 61255  iNIxjH-qoi0DW-0M2ML2DA  DsNNLmJIgYq_8kiLYvmhhg       4
#
# [61256 rows x 3 columns]

# %%
data=data[data['stars1']>3]

# %%
data1=data

# %%
df=pd.merge(data,data1,on='business_id')

# %%
df
# Out:
#                      user_id1_x             business_id  stars1_x  \
# 0        tLwr8JoGxjRNNoSenPk1ew  DSAx-FBLT0FcGC_aW_C8rA         4
# 1        tLwr8JoGxjRNNoSenPk1ew  DSAx-FBLT0FcGC_aW_C8rA         4
# 2        tLwr8JoGxjRNNoSenPk1ew  DSAx-FBLT0FcGC_aW_C8rA         4
# 3        tLwr8JoGxjRNNoSenPk1ew  DSAx-FBLT0FcGC_aW_C8rA         4
# 4        tLwr8JoGxjRNNoSenPk1ew  DSAx-FBLT0FcGC_aW_C8rA         4
# ...                         ...                     ...       ...
# 5723058  M5O7Me7VNu5b7W-jx_LhQg  YQ5nt_RTUqEdo0YkI0TNcg         5
# 5723059  M5O7Me7VNu5b7W-jx_LhQg  YQ5nt_RTUqEdo0YkI0TNcg         5
# 5723060  9LVjFd_NpaFZ-DFO1T3RlQ  znb9XlraxrdeK3h0OAMHfA         4
# 5723061  LXfKtlVWB1Eiww8-XW_2GQ  tY8u7jr_w20S_jwgdFpXAQ         4
# 5723062  iNIxjH-qoi0DW-0M2ML2DA  DsNNLmJIgYq_8kiLYvmhhg         4
#
#                      user_id1_y  stars1_y
# 0        tLwr8JoGxjRNNoSenPk1ew         4
# 1        N5bTFlG1cs1eBSTwpNKHHg         4
# 2        T3p2sDKZlWNSFC6-axt_XA         4
# 3        HqgLHcpN3q7iNLce-oEnvg         4
# 4        K7Eb8-QWfeKX3tLcVngDpA         4
# ...                         ...       ...
# 5723058  4qum1jC0B8OcFCWgM_FY6Q         5
# 5723059  M5O7Me7VNu5b7W-jx_LhQg         5
# 5723060  9LVjFd_NpaFZ-DFO1T3RlQ         4
# 5723061  LXfKtlVWB1Eiww8-XW_2GQ         4
# 5723062  iNIxjH-qoi0DW-0M2ML2DA         4
#
# [5723063 rows x 5 columns]

# %%
import seaborn as sns
b=df.groupby(['user_id1_x','user_id1_y']).count()
b=b[b['business_id']>3]
b=b.business_id
b=b.unstack(level=0)
b=b.iloc[::-1]
b=b.fillna(0)
sns.heatmap(b,vmin=0,vmax=8,center=0.5)
# Out:
# <AxesSubplot:xlabel='user_id1_x', ylabel='user_id1_y'>

# %%
a=df.groupby(['user_id1_x','user_id1_y'], as_index=False).count()
a=a[a['business_id']>3]
a=a[a.user_id1_x>a.user_id1_y]
a
# Out:
#                      user_id1_x              user_id1_y  business_id  \
# 43160    -SUfz9v2mXPZaoJH4YWTIw  -9X63yvBKJyOaQzP-Clvkw            7
# 43167    -SUfz9v2mXPZaoJH4YWTIw  -BjtuTpPO5mQtHS32NpVpA            5
# 57263    -_iOCerBQ0xfiNbZtNhfHA  -SUfz9v2mXPZaoJH4YWTIw            7
# 94423    0-mKNvwasvI1CC13QT4Z-w  -SUfz9v2mXPZaoJH4YWTIw            5
# 99738    04tkmJ-qZ9waV0t5n4_6sg  -_iOCerBQ0xfiNbZtNhfHA            4
# ...                         ...                     ...          ...
# 5294096  zrD5JRGhwpigWv8Y5Ln_0A  Wlabem0UXBVmKI9eUsCbqg            4
# 5296364  zsgH8afv2CDkn93jHtfBUQ  3cbEkaaC13_IPo2iKUYcgA            4
# 5299302  zvksa0W61MTpeRkJmiucbQ  mcDigvWlNHM3VznNMfQEnQ            4
# 5302564  zxuKNsouUK2zCf1GweuVNw  1fL1QDs1Xe5LTOdeXGtpnw            5
# 5304681  zybDLvQ8EWjQTRI6g1jOpg  Xwnf20FKuikiHcSpcEbpKQ            5
#
#          stars1_x  stars1_y
# 43160           7         7
# 43167           5         5
# 57263           7         7
# 94423           5         5
# 99738           4         4
# ...           ...       ...
# 5294096         4         4
# 5296364         4         4
# 5299302         4         4
# 5302564         5         5
# 5304681         5         5
#
# [11107 rows x 5 columns]

# %%
a.rename(columns={'user_id1_x':'user_id'},inplace=True)
df_final=pd.merge(a, df_u, on='user_id')

# %%
dic={}
i=0
for p in df_final['user_id1_y']:
    if p in df_final['friends'].values[i]:
        dic[i]=1
    else:
        dic[i]=0
    i+=1
df_final['truefriend'] = dic.values() 
df_final
# Out:
#                       user_id              user_id1_y  business_id  stars1_x  \
# 0      -SUfz9v2mXPZaoJH4YWTIw  -9X63yvBKJyOaQzP-Clvkw            7         7
# 1      -SUfz9v2mXPZaoJH4YWTIw  -BjtuTpPO5mQtHS32NpVpA            5         5
# 2      -_iOCerBQ0xfiNbZtNhfHA  -SUfz9v2mXPZaoJH4YWTIw            7         7
# 3      0-mKNvwasvI1CC13QT4Z-w  -SUfz9v2mXPZaoJH4YWTIw            5         5
# 4      04tkmJ-qZ9waV0t5n4_6sg  -_iOCerBQ0xfiNbZtNhfHA            4         4
# ...                       ...                     ...          ...       ...
# 11102  zrD5JRGhwpigWv8Y5Ln_0A  Wlabem0UXBVmKI9eUsCbqg            4         4
# 11103  zsgH8afv2CDkn93jHtfBUQ  3cbEkaaC13_IPo2iKUYcgA            4         4
# 11104  zvksa0W61MTpeRkJmiucbQ  mcDigvWlNHM3VznNMfQEnQ            4         4
# 11105  zxuKNsouUK2zCf1GweuVNw  1fL1QDs1Xe5LTOdeXGtpnw            5         5
# 11106  zybDLvQ8EWjQTRI6g1jOpg  Xwnf20FKuikiHcSpcEbpKQ            5         5
#
#        stars1_y                                            friends  truefriend
# 0             7  WLDktwuGx5x8JH1HBL9bYA, MaF1QDFTCFyoO6nn6CQJcA...           0
# 1             5  WLDktwuGx5x8JH1HBL9bYA, MaF1QDFTCFyoO6nn6CQJcA...           0
# 2             7  _QrVK0745Q7fZA08aUCQ6A, kwiS-8Ay3L1FnOdl-J8x_Q...           0
# 3             5  ZMocFA2lNMJeiKjguUKu7g, E0ht65aQxUlKsT-4nM-Isg...           0
# 4             4  q-v8elVPvKz0KvK69QSj1Q, yk73Z3dd4IJV_9SKwv0iNg...           0
# ...         ...                                                ...         ...
# 11102         4  aTrl-0ekwJqml8RJqDrZUw, XxrtSUiU9oGdE8-a3DbRcg...           0
# 11103         4  p-Hrq3oTk-IJKf2vFHXpaA, JX2r0N-Pm64bEiESzwiBGw...           0
# 11104         4                                               None           0
# 11105         5  s-zGDwiw_ZrsRkMejIiMyg, NZDyr0_Kqdx5QmWfa3PxoQ...           0
# 11106         5  FFFeLM5rk29RZn6FmGlHYQ, YsbzsfAvE0LoGWswKjPIgA...           0
#
# [11107 rows x 7 columns]

# %%
df_final['truefriend'].mean()
# Out:
# 0.11983433870532097

# %%
def suggest(user_id, a, data):
    friends=(a['user_id'][a['user_id1_y']==user_id])
    friends=friends.to_list()
    f=a['user_id1_y'][a['user_id']==user_id]
    friends.extend(f.to_list())
    lis=[]
    for p in friends:
        temp=data['business_id'][data['user_id1']==p]
        lis.extend(temp.to_list())
    lis=list(set(lis))
    l=data['business_id'][data['user_id1']==user_id]
    #sugg=[x for x in lis if x not in l]
    sugg=list(set(lis)-set(l))
    return sugg

# %%
lis=[]
temp=(data['business_id'][data['user_id1']=='tLwr8JoGxjRNNoSenPk1ew'])
lis.extend(temp.to_list())
len(lis)
# Out:
# 25

# %%
len(suggest('-SUfz9v2mXPZaoJH4YWTIw',a, data))
# Out:
# 913

# %%
five=data[data['stars1']>4]

# %%
len(suggest('-SUfz9v2mXPZaoJH4YWTIw',a, five))
# Out:
# 36

# %%
test=a['user_id'].head(100)

# %%
numres=[]
for p in test:
    numres.append(len(suggest(p ,a, five)))

# %%
import matplotlib.pyplot as plt
fig, ax=plt.subplots(1,1,figsize=(20,10))
sns.barplot(y=test, x=numres, orient="h", ax=ax, palette='colorblind')
# Out:
# <AxesSubplot:ylabel='user_id'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,10))
sns.histplot(numres, color='tab:red', ax=ax)
# Out:
# <AxesSubplot:ylabel='Count'>
