# %%
import pandas as pd
df1 = pd.read_csv('review1.csv')
df1=df1.drop(['text','review_id','funny','cool'], axis=1)

# %%
df2 = pd.read_csv('review2.csv')
df2=df2.drop(['text','review_id','funny','cool'], axis=1)

# %%
df3 = pd.read_csv('review3.csv')
df3=df3.drop(['text','review_id','funny','cool'], axis=1)

# %%
df4 = pd.read_csv('review4.csv')
df4=df4.drop(['text','review_id','funny','cool'], axis=1)

# %%
df5 = pd.read_csv('review5.csv')
df5=df5.drop(['text','review_id','funny','cool'], axis=1)

# %%
df6 = pd.read_csv('review6.csv')
df6=df6.drop(['text','review_id','funny','cool'], axis=1)

# %%
df7 = pd.read_csv('review7.csv')
df7=df7.drop(['text','review_id','funny','cool'], axis=1)

# %%
df8 = pd.read_csv('review8.csv')
df8=df8.drop(['text','review_id','funny','cool'], axis=1)

# %%
df9 = pd.read_csv('review9.csv')
df9=df9.drop(['text','review_id','funny','cool'], axis=1)

# %%
df10 = pd.read_csv('review10.csv')
df10=df10.drop(['text','review_id','funny','cool'], axis=1)

# %%
df11 = pd.read_csv('review11.csv')
df11=df11.drop(['text','review_id','funny','cool'], axis=1)

# %%
df12 = pd.read_csv('review12.csv')
df12=df12.drop(['text','review_id','funny','cool'], axis=1)

# %%
df13 = pd.read_csv('review13.csv')
df13=df13.drop(['text','review_id','funny','cool'], axis=1)

# %%
df14 = pd.read_csv('review14.csv')
df14=df14.drop(['text','review_id','funny','cool'], axis=1)

# %%
df15 = pd.read_csv('review15.csv')
df15=df15.drop(['text','review_id','funny','cool'], axis=1)

# %%
df16 = pd.read_csv('review16.csv')
df16=df16.drop(['text','review_id','funny','cool'], axis=1)

# %%
df17 = pd.read_csv('review17.csv')
df17=df17.drop(['text','review_id','funny','cool'], axis=1)

# %%
df18 = pd.read_csv('review18.csv')
df18=df18.drop(['text','review_id','funny','cool'], axis=1)

# %%
frames = [df1, df2, df3,df4, df5, df6,df7, df8, df9,df10, df11, df12,df13, df14, df15,df16, df17, df18]
result = pd.concat(frames)

# %%
df_b = pd.read_json('yelp_academic_dataset_business.json', lines=True)

# %%
df_b=df_b[df_b['city']=='Portland']
df_b.dropna( axis=0, how="any", thresh=None, subset=None, inplace=True)
df_b
# Out:
#                    business_id                        name  \
# 1       tCbdrRPZA0oiIYSmHG3J0w     Flying Elephants at PDX
# 2       bvN78flM8NLprQ1a1y5dRg              The Reclaimory
# 20      DLbEQySMW3X7KvkybpEYkw            Jasmine Nail Spa
# 23      j68RDnvOaYEwGcY9cTEHpA             Pittock Mansion
# 32      uMGsjQGT35rX4AAt1Hp9og    Laurelhurst Chiropractic
# ...                        ...                         ...
# 160521  68nXXzFyK8tzcBlv8eM3tw  McMenamins Barley Mill Pub
# 160526  Xnczteyo1nfsZXvRnx9zqg     Bashor's Team Athletics
# 160530  23URUiNssvknBern9BCbRw        St Johns Auto Center
# 160537  ER_VMRSD-9FSbw4SGGNQvA                    Seaplane
# 160561  jYgqSazE0gUyI7qq086Dzw                 Chart House
#
#                             address      city state postal_code   latitude  \
# 1               7000 NE Airport Way  Portland    OR       97218  45.588906
# 2                4720 Hawthorne Ave  Portland    OR       97214  45.511907
# 20         4370 SE King Rd, Ste 125  Portland    OR       97222  45.447598
# 23               3229 NW Pittock Dr  Portland    OR       97210  45.525259
# 32      2705 E Burnside St, Ste 213  Portland    OR       97214  45.523103
# ...                             ...       ...   ...         ...        ...
# 160521    1629 S.E. Hawthorne Blvd.  Portland    OR       97214  45.512422
# 160526        4812 N Interstate Ave  Portland    OR       97217  45.557766
# 160530            6514 N Lombard St  Portland    OR       97203  45.585576
# 160537           2266 NW Lovejoy St  Portland    OR       97210  45.529592
# 160561          5700 SW Terwilliger  Portland    OR       97239  45.483154
#
#          longitude  stars  review_count  is_open  \
# 1      -122.593331    4.0           126        1
# 2      -122.613693    4.5            13        1
# 20     -122.617427    3.0             7        0
# 23     -122.716227    4.5           406        1
# 32     -122.638005    4.5            25        1
# ...            ...    ...           ...      ...
# 160521 -122.648782    3.5           108        1
# 160526 -122.681779    3.5             7        1
# 160530 -122.733644    4.5            21        1
# 160537 -122.697685    3.5            13        0
# 160561 -122.682748    3.5           457        1
#
#                                                attributes  \
# 1       {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 2       {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 20      {'RestaurantsPriceRange2': '1', 'ByAppointment...
# 23      {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 32      {'AcceptsInsurance': 'True', 'ByAppointmentOnl...
# ...                                                   ...
# 160521  {'HasTV': 'True', 'NoiseLevel': 'u'average'', ...
# 160526  {'BusinessParking': '{'garage': False, 'street...
# 160530  {'BusinessAcceptsCreditCards': 'True', 'WiFi':...
# 160537  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 160561  {'BusinessAcceptsCreditCards': 'True', 'Outdoo...
#
#                                                categories  \
# 1       Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2       Antiques, Fashion, Used, Vintage & Consignment...
# 20                             Nail Salons, Beauty & Spas
# 23      Tours, Museums, Architectural Tours, Venues & ...
# 32      Acupuncture, Prenatal/Perinatal Care, Health &...
# ...                                                   ...
# 160521  Pubs, Breweries, Food, American (Traditional),...
# 160526  Shopping, Building Supplies, Home Services, Sp...
# 160530                Automotive, Body Shops, Auto Repair
# 160537  Fashion, Men's Clothing, Restaurants, Shopping...
# 160561  Event Planning & Services, Steakhouses, Seafoo...
#
#                                                     hours
# 1       {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 2       {'Thursday': '11:0-18:0', 'Friday': '11:0-18:0...
# 20      {'Monday': '9:30-18:0', 'Tuesday': '9:30-18:0'...
# 23      {'Monday': '0:0-0:0', 'Thursday': '10:0-16:0',...
# 32      {'Monday': '0:0-0:0', 'Tuesday': '9:0-18:0', '...
# ...                                                   ...
# 160521  {'Monday': '12:0-20:0', 'Tuesday': '12:0-20:0'...
# 160526  {'Monday': '0:0-0:0', 'Tuesday': '9:0-15:0', '...
# 160530  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...
# 160537  {'Monday': '11:0-18:0', 'Tuesday': '11:0-18:0'...
# 160561  {'Tuesday': '16:0-21:0', 'Wednesday': '16:0-21...
#
# [14237 rows x 14 columns]

# %%
df_new=df_b[df_b.categories.str.contains("Restaurants", na=False)==True]
df_new
# Out:
#                    business_id                           name  \
# 1       tCbdrRPZA0oiIYSmHG3J0w        Flying Elephants at PDX
# 36      jx91IMdGOmLOo8h_F9z39g  Cleary's Restaurant & Spirits
# 50      5PsApTz-WqhF_-8mfqGtGw                     Cafe Yumm!
# 93      HMXiuCxHDXqMH1hBpaHd9g             Whole Time Chicken
# 94      ZA3u0Nu5V6TqkcYh8U0zdg          B Street Coffee House
# ...                        ...                            ...
# 160509  ny28j9D88xot0Eq54ojpVQ                       Fratelli
# 160512  7r311z2Uq_UzHqu5hiipxA                    Thai Garden
# 160521  68nXXzFyK8tzcBlv8eM3tw     McMenamins Barley Mill Pub
# 160537  ER_VMRSD-9FSbw4SGGNQvA                       Seaplane
# 160561  jYgqSazE0gUyI7qq086Dzw                    Chart House
#
#                           address      city state postal_code   latitude  \
# 1             7000 NE Airport Way  Portland    OR       97218  45.588906
# 36             12429 NE Glisan St  Portland    OR       97230  45.526473
# 50             301 SW Morrison St  Portland    OR       97204  45.518450
# 93                                 Portland    OR       97215  45.516241
# 94             2190 W Burnside St  Portland    OR       97210  45.523074
# ...                           ...       ...   ...         ...        ...
# 160509            1230 Nw Hoyt St  Portland    OR       97209  45.527150
# 160512         SE 102nd And Stark  Portland    OR       97233  45.519297
# 160521  1629 S.E. Hawthorne Blvd.  Portland    OR       97214  45.512422
# 160537         2266 NW Lovejoy St  Portland    OR       97210  45.529592
# 160561        5700 SW Terwilliger  Portland    OR       97239  45.483154
#
#          longitude  stars  review_count  is_open  \
# 1      -122.593331    4.0           126        1
# 36     -122.535323    3.5            19        1
# 50     -122.675723    3.5           158        1
# 93     -122.597527    5.0             7        0
# 94     -122.696206    4.5           131        0
# ...            ...    ...           ...      ...
# 160509 -122.683865    3.5           131        0
# 160512 -122.558636    4.0           165        1
# 160521 -122.648782    3.5           108        1
# 160537 -122.697685    3.5            13        0
# 160561 -122.682748    3.5           457        1
#
#                                                attributes  \
# 1       {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 36      {'RestaurantsGoodForGroups': 'True', 'Alcohol'...
# 50      {'OutdoorSeating': 'True', 'GoodForKids': 'Tru...
# 93      {'OutdoorSeating': 'True', 'RestaurantsTableSe...
# 94      {'Caters': 'False', 'RestaurantsAttire': 'u'ca...
# ...                                                   ...
# 160509  {'RestaurantsReservations': 'True', 'BusinessA...
# 160512  {'RestaurantsAttire': 'u'casual'', 'Restaurant...
# 160521  {'HasTV': 'True', 'NoiseLevel': 'u'average'', ...
# 160537  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 160561  {'BusinessAcceptsCreditCards': 'True', 'Outdoo...
#
#                                                categories  \
# 1       Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 36            Nightlife, Sandwiches, Seafood, Restaurants
# 50      Vegetarian, Vegan, Sandwiches, Soup, American ...
# 93                   Food Stands, Restaurants, Sandwiches
# 94      Restaurants, Food, Sandwiches, Breakfast & Bru...
# ...                                                   ...
# 160509                               Italian, Restaurants
# 160512  Food Stands, Food, Street Vendors, Restaurants...
# 160521  Pubs, Breweries, Food, American (Traditional),...
# 160537  Fashion, Men's Clothing, Restaurants, Shopping...
# 160561  Event Planning & Services, Steakhouses, Seafoo...
#
#                                                     hours
# 1       {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 36      {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...
# 50      {'Monday': '10:0-17:0', 'Tuesday': '10:0-17:0'...
# 93      {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...
# 94      {'Monday': '6:30-15:0', 'Tuesday': '6:30-15:0'...
# ...                                                   ...
# 160509  {'Wednesday': '17:0-22:0', 'Thursday': '17:0-2...
# 160512  {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...
# 160521  {'Monday': '12:0-20:0', 'Tuesday': '12:0-20:0'...
# 160537  {'Monday': '11:0-18:0', 'Tuesday': '11:0-18:0'...
# 160561  {'Tuesday': '16:0-21:0', 'Wednesday': '16:0-21...
#
# [4877 rows x 14 columns]

# %%
res=result.rename(columns={'stars': 'rates'})
res
# Out:
#                        user_id             business_id  rates  useful  \
# 0       ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ      4       3
# 1       YoVfDbnISlW0f7abNQACIg  RA4V8pr014UyUbDvI-LW2A      4       1
# 2       eC5evKn1TWDyHCyQAwguUw  _sS2LBIGNT5NQb6PD1Vtjw      5       0
# 3       SFQ1jcnGguO0LYWnbbftAA  0AzLzHfOJgL7ROwhdww2ew      2       1
# 4       0kA0PAJ8QFMeveQWHFqz2A  8zehGz9jnxPqXtOc7KaJxA      4       0
# ...                        ...                     ...    ...     ...
# 135398  6olZ0y9oW9azON61AhwxYg  yyTtwwQ4JnQMJ2rn3W0S0g      1       0
# 135399  EPYNZQFuSKqLi-on3U9dFg  RDgwjgbu5xziFIAaNn3WCQ      1      13
# 135400  tr13Jb83h2itjyXVwaO5eA  rbuj2X4SXIc3MDul4dcxIA      5      39
# 135401  HqdmRMpNvScFxjGAB40vgQ  IRzjEZ2pX4iOpnBG7oZJ7g      2       2
# 135402  HsT8bz3-SKMk7YidwLLM6Q  pxwYIa1jZzHJ4R0Sp1cHFw      5      11
#
#                        date
# 0       2014-10-11 03:34:02
# 1       2015-07-03 20:38:25
# 2       2013-05-28 20:38:06
# 3       2010-01-08 02:29:15
# 4       2011-07-28 18:05:01
# ...                     ...
# 135398  2021-01-26 04:07:14
# 135399  2019-05-01 21:21:43
# 135400  2020-06-13 02:39:26
# 135401  2020-06-22 21:54:10
# 135402  2019-04-17 04:27:39
#
# [8635403 rows x 5 columns]

# %%
util=result[result['useful']>=5]
util
# Out:
#                        user_id             business_id  stars  useful  \
# 16      bUHweiErUJ36WGeNrPmEbA  6Hm2FmfLcU_M91TrZI5htA      5       5
# 19      jySmPCkEkJR3cWJlkEs9cw  ZW7aI5FO_3q_vSzI4_zx-Q      5       5
# 23      d01SZKYmReEar7varZB0HQ  I2OblwJG8_XzFxxoHU0vVQ      4       5
# 25      7x863PREK98UuCxYpOszIw  ISBs1ARjIFCXGWqPmGSMog      5       5
# 34      s4NgvdIfBH3UQdccWCyARg  IdXHHEUH4ebcxdRxCo3JNw      3       7
# ...                        ...                     ...    ...     ...
# 135374  xnf9I953jVkJiqBIIjWJOg  qYANgZTvhdkarq8n1m68bg      4       5
# 135375  nRRvAmz3K9jSvenAf_H4wg  CnuJ9rh9xvKJ3EaCo1xIOw      5       6
# 135399  EPYNZQFuSKqLi-on3U9dFg  RDgwjgbu5xziFIAaNn3WCQ      1      13
# 135400  tr13Jb83h2itjyXVwaO5eA  rbuj2X4SXIc3MDul4dcxIA      5      39
# 135402  HsT8bz3-SKMk7YidwLLM6Q  pxwYIa1jZzHJ4R0Sp1cHFw      5      11
#
#                        date
# 16      2014-02-05 21:09:05
# 19      2013-08-15 14:47:40
# 23      2010-05-14 14:33:54
# 25      2013-05-07 01:49:39
# 34      2009-10-13 22:20:10
# ...                     ...
# 135374  2019-07-02 02:10:16
# 135375  2020-10-02 16:41:02
# 135399  2019-05-01 21:21:43
# 135400  2020-06-13 02:39:26
# 135402  2019-04-17 04:27:39
#
# [534377 rows x 5 columns]

# %%
merged=pd.merge(df_new, res)
merged
# Out:
#                    business_id                     name              address  \
# 0       tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 1       tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 2       tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 3       tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 4       tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# ...                        ...                      ...                  ...
# 752035  GB75wPibj3IjNauaoCxyGA              Havana Cafe       910 NW 14th St
# 752036  GB75wPibj3IjNauaoCxyGA              Havana Cafe       910 NW 14th St
# 752037  GB75wPibj3IjNauaoCxyGA              Havana Cafe       910 NW 14th St
# 752038  GB75wPibj3IjNauaoCxyGA              Havana Cafe       910 NW 14th St
# 752039  GB75wPibj3IjNauaoCxyGA              Havana Cafe       910 NW 14th St
#
#             city state postal_code   latitude   longitude  stars  \
# 0       Portland    OR       97218  45.588906 -122.593331    4.0
# 1       Portland    OR       97218  45.588906 -122.593331    4.0
# 2       Portland    OR       97218  45.588906 -122.593331    4.0
# 3       Portland    OR       97218  45.588906 -122.593331    4.0
# 4       Portland    OR       97218  45.588906 -122.593331    4.0
# ...          ...   ...         ...        ...         ...    ...
# 752035  Portland    OR       97209  45.529647 -122.685153    4.0
# 752036  Portland    OR       97209  45.529647 -122.685153    4.0
# 752037  Portland    OR       97209  45.529647 -122.685153    4.0
# 752038  Portland    OR       97209  45.529647 -122.685153    4.0
# 752039  Portland    OR       97209  45.529647 -122.685153    4.0
#
#         review_count  is_open  \
# 0                126        1
# 1                126        1
# 2                126        1
# 3                126        1
# 4                126        1
# ...              ...      ...
# 752035            10        1
# 752036            10        1
# 752037            10        1
# 752038            10        1
# 752039            10        1
#
#                                                attributes  \
# 0       {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 1       {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 2       {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 3       {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 4       {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# ...                                                   ...
# 752035  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 752036  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 752037  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 752038  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 752039  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
#
#                                                categories  \
# 0       Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 1       Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2       Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 3       Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 4       Salad, Soup, Sandwiches, Delis, Restaurants, C...
# ...                                                   ...
# 752035              Cuban, Sandwiches, Restaurants, Cafes
# 752036              Cuban, Sandwiches, Restaurants, Cafes
# 752037              Cuban, Sandwiches, Restaurants, Cafes
# 752038              Cuban, Sandwiches, Restaurants, Cafes
# 752039              Cuban, Sandwiches, Restaurants, Cafes
#
#                                                     hours  \
# 0       {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 1       {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 2       {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 3       {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 4       {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# ...                                                   ...
# 752035                                               None
# 752036                                               None
# 752037                                               None
# 752038                                               None
# 752039                                               None
#
#                        user_id  rates  useful                 date
# 0       24gb1QBBEl2xHtVeTzDsCQ      4       1  2012-07-16 05:04:05
# 1       AsDPajAdVBsXydg60AIsdw      5       0  2015-04-28 21:11:10
# 2       Eypq5gLLjCapBVVnMw_MyA      4       0  2015-11-18 18:50:05
# 3       X568BojbbH6cAxqXU5zLwA      5       0  2011-11-30 20:15:41
# 4       gQMsoHpjmzBmBQkkefrLXw      5       2  2016-08-12 23:47:28
# ...                        ...    ...     ...                  ...
# 752035  piw1IjNOORH4yfMuVNoU3A      4       1  2020-09-30 16:15:45
# 752036  HfF4lqJIw3px1_KZ4-Y3nA      5       1  2020-08-30 00:34:42
# 752037  OOVvCyoUcYzwEVdh8bnkXQ      5       0  2020-10-03 21:40:33
# 752038  Z6ay7Ku6uu0anxSsNJUAAw      5       0  2020-08-25 19:19:34
# 752039  oHqPHNMtQwbA-JVF5gccUg      2       0  2021-01-13 01:22:27
#
# [752040 rows x 18 columns]

# %%
merged=merged[merged['useful']>=4]
merged
# Out:
#                    business_id                     name              address  \
# 19      tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 20      tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 48      tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 50      tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 58      tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# ...                        ...                      ...                  ...
# 751983  jYgqSazE0gUyI7qq086Dzw              Chart House  5700 SW Terwilliger
# 751996  jYgqSazE0gUyI7qq086Dzw              Chart House  5700 SW Terwilliger
# 752003  jYgqSazE0gUyI7qq086Dzw              Chart House  5700 SW Terwilliger
# 752021  jYgqSazE0gUyI7qq086Dzw              Chart House  5700 SW Terwilliger
# 752024  jYgqSazE0gUyI7qq086Dzw              Chart House  5700 SW Terwilliger
#
#             city state postal_code   latitude   longitude  stars  \
# 19      Portland    OR       97218  45.588906 -122.593331    4.0
# 20      Portland    OR       97218  45.588906 -122.593331    4.0
# 48      Portland    OR       97218  45.588906 -122.593331    4.0
# 50      Portland    OR       97218  45.588906 -122.593331    4.0
# 58      Portland    OR       97218  45.588906 -122.593331    4.0
# ...          ...   ...         ...        ...         ...    ...
# 751983  Portland    OR       97239  45.483154 -122.682748    3.5
# 751996  Portland    OR       97239  45.483154 -122.682748    3.5
# 752003  Portland    OR       97239  45.483154 -122.682748    3.5
# 752021  Portland    OR       97239  45.483154 -122.682748    3.5
# 752024  Portland    OR       97239  45.483154 -122.682748    3.5
#
#         review_count  is_open  \
# 19               126        1
# 20               126        1
# 48               126        1
# 50               126        1
# 58               126        1
# ...              ...      ...
# 751983           457        1
# 751996           457        1
# 752003           457        1
# 752021           457        1
# 752024           457        1
#
#                                                attributes  \
# 19      {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 20      {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 48      {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 50      {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 58      {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# ...                                                   ...
# 751983  {'BusinessAcceptsCreditCards': 'True', 'Outdoo...
# 751996  {'BusinessAcceptsCreditCards': 'True', 'Outdoo...
# 752003  {'BusinessAcceptsCreditCards': 'True', 'Outdoo...
# 752021  {'BusinessAcceptsCreditCards': 'True', 'Outdoo...
# 752024  {'BusinessAcceptsCreditCards': 'True', 'Outdoo...
#
#                                                categories  \
# 19      Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 20      Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 48      Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 50      Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 58      Salad, Soup, Sandwiches, Delis, Restaurants, C...
# ...                                                   ...
# 751983  Event Planning & Services, Steakhouses, Seafoo...
# 751996  Event Planning & Services, Steakhouses, Seafoo...
# 752003  Event Planning & Services, Steakhouses, Seafoo...
# 752021  Event Planning & Services, Steakhouses, Seafoo...
# 752024  Event Planning & Services, Steakhouses, Seafoo...
#
#                                                     hours  \
# 19      {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 20      {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 48      {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 50      {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 58      {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# ...                                                   ...
# 751983  {'Tuesday': '16:0-21:0', 'Wednesday': '16:0-21...
# 751996  {'Tuesday': '16:0-21:0', 'Wednesday': '16:0-21...
# 752003  {'Tuesday': '16:0-21:0', 'Wednesday': '16:0-21...
# 752021  {'Tuesday': '16:0-21:0', 'Wednesday': '16:0-21...
# 752024  {'Tuesday': '16:0-21:0', 'Wednesday': '16:0-21...
#
#                        user_id  rates  useful                 date
# 19      Ri1nrLjmtQoDLnULZal3PA      5       7  2010-12-01 07:07:09
# 20      HFECrzYDpgbS5EmTBtj2zQ      4       6  2011-11-05 02:25:19
# 48      DpG3dtVqOsGmKFsNL1MJyA      5       4  2015-06-13 19:24:14
# 50      fG-K5NglgWxHg8PNu62afg      5       9  2011-12-13 00:25:44
# 58      640JloHIU4jEjdVrjlU68A      4       7  2015-06-28 14:04:40
# ...                        ...    ...     ...                  ...
# 751983  8lEywHSvti2UjFP8ODbnHg      3      13  2019-03-25 19:05:22
# 751996  6eilRaUDPl1Vz8liYPpZjA      4       6  2020-03-16 06:00:40
# 752003  G1DtOw86TtPYtllePlMAdw      4       4  2018-11-18 23:46:49
# 752021  G1DtOw86TtPYtllePlMAdw      3       5  2018-12-20 23:43:12
# 752024  DEjRvKAJWCrjCaEP-FVJ-g      2       6  2017-12-05 19:32:56
#
# [53397 rows x 18 columns]

# %%
grouped=merged.groupby(by='business_id')
meanrate=grouped['rates'].mean()

# %%
#pd.merge(df_new,meanrate)
meanrate=meanrate.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-63d33e729146> in <module>
#       1 #pd.merge(df_new,meanrate)
# ----> 2 meanrate=meanrate.to_frame()
#       3 meanrate.reset_index()
#
# /Applications/anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
meanrate=meanrate.reset_index()

# %%
pd.merge(df_new,meanrate)
# Out:
#                  business_id                           name  \
# 0     tCbdrRPZA0oiIYSmHG3J0w        Flying Elephants at PDX
# 1     jx91IMdGOmLOo8h_F9z39g  Cleary's Restaurant & Spirits
# 2     5PsApTz-WqhF_-8mfqGtGw                     Cafe Yumm!
# 3     ZA3u0Nu5V6TqkcYh8U0zdg          B Street Coffee House
# 4     aTAe3uMYBEwU0FbTMFEI5g                   Urban Pantry
# ...                      ...                            ...
# 4114  ny28j9D88xot0Eq54ojpVQ                       Fratelli
# 4115  7r311z2Uq_UzHqu5hiipxA                    Thai Garden
# 4116  68nXXzFyK8tzcBlv8eM3tw     McMenamins Barley Mill Pub
# 4117  ER_VMRSD-9FSbw4SGGNQvA                       Seaplane
# 4118  jYgqSazE0gUyI7qq086Dzw                    Chart House
#
#                         address      city state postal_code   latitude  \
# 0           7000 NE Airport Way  Portland    OR       97218  45.588906
# 1            12429 NE Glisan St  Portland    OR       97230  45.526473
# 2            301 SW Morrison St  Portland    OR       97204  45.518450
# 3            2190 W Burnside St  Portland    OR       97210  45.523074
# 4            1128 NW Lovejoy St  Portland    OR       97209  45.529939
# ...                         ...       ...   ...         ...        ...
# 4114            1230 Nw Hoyt St  Portland    OR       97209  45.527150
# 4115         SE 102nd And Stark  Portland    OR       97233  45.519297
# 4116  1629 S.E. Hawthorne Blvd.  Portland    OR       97214  45.512422
# 4117         2266 NW Lovejoy St  Portland    OR       97210  45.529592
# 4118        5700 SW Terwilliger  Portland    OR       97239  45.483154
#
#        longitude  stars  review_count  is_open  \
# 0    -122.593331    4.0           126        1
# 1    -122.535323    3.5            19        1
# 2    -122.675723    3.5           158        1
# 3    -122.696206    4.5           131        0
# 4    -122.682932    3.5            26        1
# ...          ...    ...           ...      ...
# 4114 -122.683865    3.5           131        0
# 4115 -122.558636    4.0           165        1
# 4116 -122.648782    3.5           108        1
# 4117 -122.697685    3.5            13        0
# 4118 -122.682748    3.5           457        1
#
#                                              attributes  \
# 0     {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 1     {'RestaurantsGoodForGroups': 'True', 'Alcohol'...
# 2     {'OutdoorSeating': 'True', 'GoodForKids': 'Tru...
# 3     {'Caters': 'False', 'RestaurantsAttire': 'u'ca...
# 4     {'HasTV': 'False', 'NoiseLevel': 'u'quiet'', '...
# ...                                                 ...
# 4114  {'RestaurantsReservations': 'True', 'BusinessA...
# 4115  {'RestaurantsAttire': 'u'casual'', 'Restaurant...
# 4116  {'HasTV': 'True', 'NoiseLevel': 'u'average'', ...
# 4117  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 4118  {'BusinessAcceptsCreditCards': 'True', 'Outdoo...
#
#                                              categories  \
# 0     Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 1           Nightlife, Sandwiches, Seafood, Restaurants
# 2     Vegetarian, Vegan, Sandwiches, Soup, American ...
# 3     Restaurants, Food, Sandwiches, Breakfast & Bru...
# 4     Do-It-Yourself Food, Restaurants, American (Tr...
# ...                                                 ...
# 4114                               Italian, Restaurants
# 4115  Food Stands, Food, Street Vendors, Restaurants...
# 4116  Pubs, Breweries, Food, American (Traditional),...
# 4117  Fashion, Men's Clothing, Restaurants, Shopping...
# 4118  Event Planning & Services, Steakhouses, Seafoo...
#
#                                                   hours     rates
# 0     {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...  4.636364
# 1     {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...  2.000000
# 2     {'Monday': '10:0-17:0', 'Tuesday': '10:0-17:0'...  2.714286
# 3     {'Monday': '6:30-15:0', 'Tuesday': '6:30-15:0'...  3.000000
# 4     {'Monday': '0:0-0:0', 'Tuesday': '10:0-19:0', ...  4.666667
# ...                                                 ...       ...
# 4114  {'Wednesday': '17:0-22:0', 'Thursday': '17:0-2...  3.250000
# 4115  {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...  4.500000
# 4116  {'Monday': '12:0-20:0', 'Tuesday': '12:0-20:0'...  2.833333
# 4117  {'Monday': '11:0-18:0', 'Tuesday': '11:0-18:0'...  4.000000
# 4118  {'Tuesday': '16:0-21:0', 'Wednesday': '16:0-21...  2.212121
#
# [4119 rows x 15 columns]
