# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_json('yelp_academic_dataset_business.json', lines=True)

# %%
#df1 = pd.read_csv('review1.csv')
#df1=df1.drop(['text','review_id','funny','cool'], axis=1)
#df2 = pd.read_csv('review2.csv')
#df2=df2.drop(['text','review_id','funny','cool'], axis=1)
#df3 = pd.read_csv('review3.csv')
#df3=df3.drop(['text','review_id','funny','cool'], axis=1)
#df4 = pd.read_csv('review4.csv')
#df4=df4.drop(['text','review_id','funny','cool'], axis=1)
#df5 = pd.read_csv('review5.csv')
#df5=df5.drop(['text','review_id','funny','cool'], axis=1)
#df6 = pd.read_csv('review6.csv')
#df6=df6.drop(['text','review_id','funny','cool'], axis=1)
#df7 = pd.read_csv('review7.csv')
#df7=df7.drop(['text','review_id','funny','cool'], axis=1)
#df8 = pd.read_csv('review8.csv')
#df8=df8.drop(['text','review_id','funny','cool'], axis=1)
#df9 = pd.read_csv('review9.csv')
#df9=df9.drop(['text','review_id','funny','cool'], axis=1)
#df10 = pd.read_csv('review10.csv')
#df10=df10.drop(['text','review_id','funny','cool'], axis=1)
#df11 = pd.read_csv('review11.csv')
#df11=df11.drop(['text','review_id','funny','cool'], axis=1)
#df12 = pd.read_csv('review12.csv')
#df12=df12.drop(['text','review_id','funny','cool'], axis=1)
#df13 = pd.read_csv('review13.csv')
#df13=df13.drop(['text','review_id','funny','cool'], axis=1)
#df14 = pd.read_csv('review14.csv')
#df14=df14.drop(['text','review_id','funny','cool'], axis=1)
#df15 = pd.read_csv('review15.csv')
#df15=df15.drop(['text','review_id','funny','cool'], axis=1)
#df16 = pd.read_csv('review16.csv')
#df16=df16.drop(['text','review_id','funny','cool'], axis=1)
#df17 = pd.read_csv('review17.csv')
#df17=df17.drop(['text','review_id','funny','cool'], axis=1)
#df18 = pd.read_csv('review18.csv')
#df18=df18.drop(['text','review_id','funny','cool'], axis=1)

# %%
list_df = []
for i in range(1, 19):
    print(i)
    df = pd.read_csv('review'+str(i)+'.csv')
    df.drop(['text','review_id','user_id','funny','cool'], axis=1)
    list_df.append(df)
result = pd.concat(list_df)

# %%
#create a dataframe with all the reviews but without the text which is not relevant for the analysis
#frames = [df1, df2, df3,df4, df5, df6,df7, df8, df9,df10, df11, df12,df13, df14, df15,df16, df17, df18]
#result = pd.concat(frames)

# %%
data=data.drop(['name','address','postal_code','latitude','longitude','stars','attributes','categories','hours'],axis=1)

# %%
data
# Out:
#                    business_id               city state  review_count  is_open
# 0       6iYb2HFDywm3zjuRg0shjw            Boulder    CO            86        1
# 1       tCbdrRPZA0oiIYSmHG3J0w           Portland    OR           126        1
# 2       bvN78flM8NLprQ1a1y5dRg           Portland    OR            13        1
# 3       oaepsyvc0J17qwi8cfrOWg        Orange City    FL             8        1
# 4       PE9uqAjdw0E4-8mjGl3wVA            Atlanta    GA            14        1
# ...                        ...                ...   ...           ...      ...
# 160580  D2mHoIDXx9N8mS1pGoKV9Q             Austin    TX             8        1
# 160581  bQX-kwVTyZgcdZGEPzce6Q            Orlando    FL            18        1
# 160582  wvFZ06nmPmQ2-IVoPqVYLA            Orlando    FL             8        0
# 160583  GB75wPibj3IjNauaoCxyGA           Portland    OR            10        1
# 160584  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL            82        0
#
# [160585 rows x 5 columns]

# %%
data['review_count'].sum()
# Out:
# 8344727

# %%
result=result.rename(columns={'stars':'rates'})
result
# Out:
#                        user_id             business_id  rates  useful  \
# 0       ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ      4       3
# 1       YoVfDbnISlW0f7abNQACIg  RA4V8pr014UyUbDvI-LW2A      4       1
# 2       eC5evKn1TWDyHCyQAwguUw  _sS2LBIGNT5NQb6PD1Vtjw      5       0
# 3       SFQ1jcnGguO0LYWnbbftAA  0AzLzHfOJgL7ROwhdww2ew      2       1
# 4       0kA0PAJ8QFMeveQWHFqz2A  8zehGz9jnxPqXtOc7KaJxA      4       0
# ...                        ...                     ...    ...     ...
# 135398  6olZ0y9oW9azON61AhwxYg  yyTtwwQ4JnQMJ2rn3W0S0g      1       0
# 135399  EPYNZQFuSKqLi-on3U9dFg  RDgwjgbu5xziFIAaNn3WCQ      1      13
# 135400  tr13Jb83h2itjyXVwaO5eA  rbuj2X4SXIc3MDul4dcxIA      5      39
# 135401  HqdmRMpNvScFxjGAB40vgQ  IRzjEZ2pX4iOpnBG7oZJ7g      2       2
# 135402  HsT8bz3-SKMk7YidwLLM6Q  pxwYIa1jZzHJ4R0Sp1cHFw      5      11
#
#                        date
# 0       2014-10-11 03:34:02
# 1       2015-07-03 20:38:25
# 2       2013-05-28 20:38:06
# 3       2010-01-08 02:29:15
# 4       2011-07-28 18:05:01
# ...                     ...
# 135398  2021-01-26 04:07:14
# 135399  2019-05-01 21:21:43
# 135400  2020-06-13 02:39:26
# 135401  2020-06-22 21:54:10
# 135402  2019-04-17 04:27:39
#
# [8635403 rows x 5 columns]

# %%
#we can notice that there is a mistake in the review_count or we maybe have too many review

# %%
result.dropna()
result
#there are no empty review
# Out:
#                        user_id             business_id  rates  useful  \
# 0       ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ      4       3
# 1       YoVfDbnISlW0f7abNQACIg  RA4V8pr014UyUbDvI-LW2A      4       1
# 2       eC5evKn1TWDyHCyQAwguUw  _sS2LBIGNT5NQb6PD1Vtjw      5       0
# 3       SFQ1jcnGguO0LYWnbbftAA  0AzLzHfOJgL7ROwhdww2ew      2       1
# 4       0kA0PAJ8QFMeveQWHFqz2A  8zehGz9jnxPqXtOc7KaJxA      4       0
# ...                        ...                     ...    ...     ...
# 135398  6olZ0y9oW9azON61AhwxYg  yyTtwwQ4JnQMJ2rn3W0S0g      1       0
# 135399  EPYNZQFuSKqLi-on3U9dFg  RDgwjgbu5xziFIAaNn3WCQ      1      13
# 135400  tr13Jb83h2itjyXVwaO5eA  rbuj2X4SXIc3MDul4dcxIA      5      39
# 135401  HqdmRMpNvScFxjGAB40vgQ  IRzjEZ2pX4iOpnBG7oZJ7g      2       2
# 135402  HsT8bz3-SKMk7YidwLLM6Q  pxwYIa1jZzHJ4R0Sp1cHFw      5      11
#
#                        date
# 0       2014-10-11 03:34:02
# 1       2015-07-03 20:38:25
# 2       2013-05-28 20:38:06
# 3       2010-01-08 02:29:15
# 4       2011-07-28 18:05:01
# ...                     ...
# 135398  2021-01-26 04:07:14
# 135399  2019-05-01 21:21:43
# 135400  2020-06-13 02:39:26
# 135401  2020-06-22 21:54:10
# 135402  2019-04-17 04:27:39
#
# [8635403 rows x 5 columns]

# %%
merged=pd.merge(data,result)
merged
# Out:
#                     business_id               city state  review_count  \
# 0        6iYb2HFDywm3zjuRg0shjw            Boulder    CO            86
# 1        6iYb2HFDywm3zjuRg0shjw            Boulder    CO            86
# 2        6iYb2HFDywm3zjuRg0shjw            Boulder    CO            86
# 3        6iYb2HFDywm3zjuRg0shjw            Boulder    CO            86
# 4        6iYb2HFDywm3zjuRg0shjw            Boulder    CO            86
# ...                         ...                ...   ...           ...
# 8635398  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL            82
# 8635399  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL            82
# 8635400  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL            82
# 8635401  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL            82
# 8635402  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL            82
#
#          is_open                 user_id  rates  useful                 date
# 0              1  93z0yh-sUpGZS-cSKu6xxA      5       1  2018-03-04 00:59:21
# 1              1  Q_CZIvnsDHjpls-EPzzG7Q      2       0  2018-08-14 05:22:00
# 2              1  rqxTSFFj5fZNmabY1fmTlw      5       0  2018-03-17 14:22:48
# 3              1  vNPxlt5f50q0e2nVAScW3Q      4       0  2018-04-04 21:16:50
# 4              1  eXRC79iX60xwA1UuGRuWNg      4       0  2018-04-28 19:17:04
# ...          ...                     ...    ...     ...                  ...
# 8635398        0  yl1UFGT5xxVKufxOU6dX8w      5       0  2017-01-26 01:53:31
# 8635399        0  m1aFkGBDiNYNsrnMOaVUbQ      5       0  2016-06-30 00:01:08
# 8635400        0  hCywxv9U1-V64lOisRb5ZA      5       0  2017-02-20 14:50:47
# 8635401        0  HhjxPMYcRYtLvLVfISaI8g      5       0  2015-11-21 00:53:12
# 8635402        0  _6MeLhKFCiHTMphTGS8jWg      4       0  2015-09-19 13:19:32
#
# [8635403 rows x 9 columns]

# %%
grouped=merged.groupby(by='business_id')
real_count=grouped['review_count'].count()

# %%
real_count=real_count.to_frame().reset_index()
real_count=real_count.rename(columns={'review_count':'real_count'})
real_count
# Out:
#                    business_id  real_count
# 0       --0DF12EMHYI8XIgoFha6A           6
# 1       --0r8K_AQ4FZfLsX3ZYRDA           5
# 2       --0zrn43LEaB4jUWTQH_Bg           6
# 3       --164t1nclzzmca7eDiJMw         147
# 4       --2aF9NhXnNVpDV0KS3xBQ           9
# ...                        ...         ...
# 160580  zzpmoTVq4yn86U7ArHyFBQ          36
# 160581  zzqq8J7Pibxod1YcknlkWA          10
# 160582  zzwK-TJsCJX5wZrdtKemPg          22
# 160583  zzxIO4bjWCQrvCJ0O5mmvA           5
# 160584  zzzKmD9Mj6WtJwJUhA_1dg           8
#
# [160585 rows x 2 columns]

# %%
data_real=pd.merge(data,real_count)
data_real=data_real.drop('review_count',axis=1)
data_real
#we replace the review_count with a real count which is right
# Out:
#                    business_id               city state  is_open  real_count
# 0       6iYb2HFDywm3zjuRg0shjw            Boulder    CO        1          86
# 1       tCbdrRPZA0oiIYSmHG3J0w           Portland    OR        1         129
# 2       bvN78flM8NLprQ1a1y5dRg           Portland    OR        1          13
# 3       oaepsyvc0J17qwi8cfrOWg        Orange City    FL        1           9
# 4       PE9uqAjdw0E4-8mjGl3wVA            Atlanta    GA        1          14
# ...                        ...                ...   ...      ...         ...
# 160580  D2mHoIDXx9N8mS1pGoKV9Q             Austin    TX        1           8
# 160581  bQX-kwVTyZgcdZGEPzce6Q            Orlando    FL        1          19
# 160582  wvFZ06nmPmQ2-IVoPqVYLA            Orlando    FL        0           8
# 160583  GB75wPibj3IjNauaoCxyGA           Portland    OR        1          10
# 160584  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL        0          86
#
# [160585 rows x 5 columns]

# %%
#now we can merge our data
real_merge=pd.merge(data_real,result)
real_merge
# Out:
#                     business_id               city state  is_open  real_count  \
# 0        6iYb2HFDywm3zjuRg0shjw            Boulder    CO        1          86
# 1        6iYb2HFDywm3zjuRg0shjw            Boulder    CO        1          86
# 2        6iYb2HFDywm3zjuRg0shjw            Boulder    CO        1          86
# 3        6iYb2HFDywm3zjuRg0shjw            Boulder    CO        1          86
# 4        6iYb2HFDywm3zjuRg0shjw            Boulder    CO        1          86
# ...                         ...                ...   ...      ...         ...
# 8635398  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL        0          86
# 8635399  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL        0          86
# 8635400  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL        0          86
# 8635401  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL        0          86
# 8635402  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL        0          86
#
#                         user_id  rates  useful                 date
# 0        93z0yh-sUpGZS-cSKu6xxA      5       1  2018-03-04 00:59:21
# 1        Q_CZIvnsDHjpls-EPzzG7Q      2       0  2018-08-14 05:22:00
# 2        rqxTSFFj5fZNmabY1fmTlw      5       0  2018-03-17 14:22:48
# 3        vNPxlt5f50q0e2nVAScW3Q      4       0  2018-04-04 21:16:50
# 4        eXRC79iX60xwA1UuGRuWNg      4       0  2018-04-28 19:17:04
# ...                         ...    ...     ...                  ...
# 8635398  yl1UFGT5xxVKufxOU6dX8w      5       0  2017-01-26 01:53:31
# 8635399  m1aFkGBDiNYNsrnMOaVUbQ      5       0  2016-06-30 00:01:08
# 8635400  hCywxv9U1-V64lOisRb5ZA      5       0  2017-02-20 14:50:47
# 8635401  HhjxPMYcRYtLvLVfISaI8g      5       0  2015-11-21 00:53:12
# 8635402  _6MeLhKFCiHTMphTGS8jWg      4       0  2015-09-19 13:19:32
#
# [8635403 rows x 9 columns]

# %%
real_merge['date'].max()
# Out:
# '2021-01-28 15:38:54'

# %% [markdown]
# as we can see there is a big amount of reviews which means that the app is actually much used but let us see in the
# detail how much is used

# %%
#firstly we have to keep only the year of the reviews
dates=[]
for st in real_merge['date']:
    dates.append(st.split('-',1)[0])

# %%
real_merge['dates']=dates

# %%
real_merge=real_merge.drop('date',axis=1)
real_merge
# Out:
#                     business_id               city state  is_open  real_count  \
# 0        6iYb2HFDywm3zjuRg0shjw            Boulder    CO        1          86
# 1        6iYb2HFDywm3zjuRg0shjw            Boulder    CO        1          86
# 2        6iYb2HFDywm3zjuRg0shjw            Boulder    CO        1          86
# 3        6iYb2HFDywm3zjuRg0shjw            Boulder    CO        1          86
# 4        6iYb2HFDywm3zjuRg0shjw            Boulder    CO        1          86
# ...                         ...                ...   ...      ...         ...
# 8635398  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL        0          86
# 8635399  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL        0          86
# 8635400  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL        0          86
# 8635401  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL        0          86
# 8635402  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL        0          86
#
#                         user_id  rates  useful dates
# 0        93z0yh-sUpGZS-cSKu6xxA      5       1  2018
# 1        Q_CZIvnsDHjpls-EPzzG7Q      2       0  2018
# 2        rqxTSFFj5fZNmabY1fmTlw      5       0  2018
# 3        vNPxlt5f50q0e2nVAScW3Q      4       0  2018
# 4        eXRC79iX60xwA1UuGRuWNg      4       0  2018
# ...                         ...    ...     ...   ...
# 8635398  yl1UFGT5xxVKufxOU6dX8w      5       0  2017
# 8635399  m1aFkGBDiNYNsrnMOaVUbQ      5       0  2016
# 8635400  hCywxv9U1-V64lOisRb5ZA      5       0  2017
# 8635401  HhjxPMYcRYtLvLVfISaI8g      5       0  2015
# 8635402  _6MeLhKFCiHTMphTGS8jWg      4       0  2015
#
# [8635403 rows x 9 columns]

# %% [markdown]
# We first focus on the development of Yelp app during the entire year

# %%
gpy=real_merge.groupby(by='dates')
gpy=gpy['rates'].count().to_frame().reset_index()
gpy
# Out:
#    dates    rates
# 0   2004       52
# 1   2005     6439
# 2   2006    23819
# 3   2007    71916
# 4   2008   150436
# 5   2009   213797
# 6   2010   317583
# 7   2011   431192
# 8   2012   472441
# 9   2013   555740
# 10  2014   726119
# 11  2015   907529
# 12  2016   960527
# 13  2017  1029557
# 14  2018  1084335
# 15  2019  1037569
# 16  2020   601891
# 17  2021    44461

# %%
import seaborn as sns
fig, ax=plt.subplots(1,1,figsize=(20,10))
#ax.set_yscale('log')
sns.barplot(data=gpy,x='dates',y='rates',palette='colorblind',ax=ax)
plt.ylabel('number_of_reviews')
plt.show()

# %% [markdown]
# We can see that the app had a rapid increase in the years we cannot count 2020 and 2021 as normal years because of covid-19. anyway the app has a big number of reviews which makes it really useful for many analysis on shops.

# %% [markdown]
# we now vizualize the number of new users of Yelp app every year

# %%
enter_user=real_merge.groupby(by='user_id')['dates'].min().to_frame().reset_index()
enter_user
# Out:
#                         user_id dates
# 0        ---2PmXbF47D870stH1jqA  2015
# 1        ---7FS-3SMy-cnnIPHcW9w  2019
# 2        ---fQxo-9tYZAkyWYrSfdA  2020
# 3        ---r2Fuca3t1PT3oalARQQ  2013
# 4        ---sEqd6eCGsnr8nOXrkDw  2017
# ...                         ...   ...
# 2189452  zzzPq8j7z2qR1oYqQTJxUg  2016
# 2189453  zzz_yXv7Z_JRT3tQmEo5rw  2017
# 2189454  zzzcuxFaP_FvdIB-fbP9iA  2014
# 2189455  zzzl5-rnSu3jclcANGsLgg  2019
# 2189456  zzzqnB-6DlYUbqAPxUxg4A  2017
#
# [2189457 rows x 2 columns]

# %%
enter_user=enter_user.rename(columns={'dates':'registration_year'})
enter_user=enter_user.sort_values('registration_year')
enter_user
# Out:
#                         user_id registration_year
# 761406   LFLpi-FfgDW4zpcdz3hfSQ              2004
# 249612   6IJvrFm0X3OTy6HoDWaLpg              2004
# 1031250  T7sGPimU6yTg-Rl3cAk5PA              2004
# 32714    -xoI1iImivj9SgltLsgQGQ              2004
# 2139937  yYSBB5q7bY-qSVvmMgk4FA              2004
# ...                         ...               ...
# 412747   B2O4uTYtuq0P63NW3B9EPw              2021
# 1855345  qDeLn-lM5uxnjHwvswTN9w              2021
# 778326   LjzdfmFXXkBzK-JxudZVcQ              2021
# 1568070  hp8Uo_0ePBJj8ynKLXSWFA              2021
# 716929   JwttR7TtFvTsddPWszZxMw              2021
#
# [2189457 rows x 2 columns]

# %%
fig, ax=plt.subplots(1,1,figsize=(20,10))
#ax.set_yscale('log')
sns.countplot(data=enter_user,x='registration_year',palette='colorblind',ax=ax)
plt.ylabel('number_of_new_users')
plt.show()

# %%
df_u = pd.read_json('yelp_academic_dataset_user.json', lines=True)
print(len(df_u[df_u['review_count']>10]))
print(len(df_u[df_u['review_count']>30]))
# Out:
# 726250
# 302579

# %%
rev_us_tot=real_merge.groupby(by=['dates','user_id'])['rates'].count().to_frame().reset_index()
rev_us_tot
# Out:
#         dates                 user_id  rates
# 0        2004  -xoI1iImivj9SgltLsgQGQ      7
# 1        2004  6IJvrFm0X3OTy6HoDWaLpg      4
# 2        2004  LFLpi-FfgDW4zpcdz3hfSQ      2
# 3        2004  RU7bd3h2f6pBlf8BfAyxGQ      1
# 4        2004  Rkhm3bht88rhk5pR3kF3FA      2
# ...       ...                     ...    ...
# 3589381  2021  zz_pySZjWk-qQNMTyLvuTA      1
# 3589382  2021  zziWJMYwDjyVi7kJmgRUvg      1
# 3589383  2021  zzj7xGYYue-141llNYG7BQ      1
# 3589384  2021  zzj8cLocwSe1tZiiHddwBg      1
# 3589385  2021  zzvQiBdoT9Vd72h4Eh0_Bg      1
#
# [3589386 rows x 3 columns]

# %%
years=rev_us_tot['dates'].unique()
us_rev_per_year=[]
for year in years:
    us_rev_per_year.append(rev_us_tot[rev_us_tot['dates']==year]['rates'].mean())

# %%
rev_per_us=pd.DataFrame()
rev_per_us['year']=years
rev_per_us['rev_per_us_per_year']=us_rev_per_year

# %%
fig, ax=plt.subplots(1,1,figsize=(20,10))
#ax.set_yscale('log')
sns.barplot(data=rev_per_us,x='year',y='rev_per_us_per_year',palette='colorblind',ax=ax)
#plt.ylabel('number_of_new_users')
plt.show()

# %% [markdown]
# the results are really surprising because the increase of Yelp app was really rapid it is surely very interesting to use this dataset

# %% [markdown]
# We now vizualize the amount of new shops that are part of Yelp app

# %%
enter_shops=real_merge.groupby(by='business_id')['dates'].min().to_frame().reset_index()
enter_shops
# Out:
#                    business_id dates
# 0       --0DF12EMHYI8XIgoFha6A  2014
# 1       --0r8K_AQ4FZfLsX3ZYRDA  2017
# 2       --0zrn43LEaB4jUWTQH_Bg  2011
# 3       --164t1nclzzmca7eDiJMw  2009
# 4       --2aF9NhXnNVpDV0KS3xBQ  2008
# ...                        ...   ...
# 160580  zzpmoTVq4yn86U7ArHyFBQ  2020
# 160581  zzqq8J7Pibxod1YcknlkWA  2014
# 160582  zzwK-TJsCJX5wZrdtKemPg  2007
# 160583  zzxIO4bjWCQrvCJ0O5mmvA  2011
# 160584  zzzKmD9Mj6WtJwJUhA_1dg  2009
#
# [160585 rows x 2 columns]

# %%
enter_shops=enter_shops.rename(columns={'dates':'registration_year'})
enter_shops=enter_shops.sort_values('registration_year')
enter_shops
# Out:
#                    business_id registration_year
# 708     -I4bxb04YkCSNCbFWto7Gw              2004
# 39423   E_vKoJ0zvpfAcEkQGS4d2A              2004
# 47610   Hnx34LxtfW4XV0gZ18zMBg              2004
# 82735   VvhGHzjyOdStXblX88xk8w              2004
# 44023   GPhnm_rcjkbc_b96DVS5HQ              2004
# ...                        ...               ...
# 132581  ooNOrdHdhmhS7guiIpDDuA              2021
# 45636   H12AT1cT1RSRk_muB5fqnw              2021
# 67883   PvfUahCnlK7kocPw20OnHA              2021
# 1994    -ncunpZ1SM-VF3plXoiyjw              2021
# 65746   P264CzjXo11x4a65rzFQdQ              2021
#
# [160585 rows x 2 columns]

# %%
fig, ax=plt.subplots(1,1,figsize=(20,10))
#ax.set_yscale('log')
sns.countplot(data=enter_shops,x='registration_year',palette='colorblind',ax=ax)
plt.ylabel('number_of_new_shops')
plt.show()

# %%
#gpy['new_users']=
new_users=enter_user.groupby(by='registration_year')['user_id'].count().to_frame().reset_index()
new_shop=enter_shops.groupby(by='registration_year')['business_id'].count().to_frame().reset_index()
#enter_shops
#gpy=gpy.drop('new_users',axis=1)
#gpy
gpy['new_users']=new_users['user_id']
#gpy
#new_users
gpy['new_shops']=new_shop['business_id']
gpy
# Out:
#    dates    rates  new_users  new_shops
# 0   2004       52         15         45
# 1   2005     6439        388       2583
# 2   2006    23819       2164       5531
# 3   2007    71916       7859       9470
# 4   2008   150436      18761      14947
# 5   2009   213797      36263      11981
# 6   2010   317583      58973      14463
# 7   2011   431192      91901      15262
# 8   2012   472441     106695      13964
# 9   2013   555740     137964      13369
# 10  2014   726119     192176      13144
# 11  2015   907529     244989      12560
# 12  2016   960527     268611      10203
# 13  2017  1029557     286208       8438
# 14  2018  1084335     295392       7165
# 15  2019  1037569     279336       5149
# 16  2020   601891     149902       2274
# 17  2021    44461      11860         37

# %%
gpy[['rates','new_users','new_shops']].corr(method='spearman')
# Out:
#               rates  new_users  new_shops
# rates      1.000000   0.995872   0.180599
# new_users  0.995872   1.000000   0.170279
# new_shops  0.180599   0.170279   1.000000

# %%
from scipy import stats
print(stats.pearsonr(gpy['rates'],gpy['new_shops']))
print(stats.spearmanr(gpy['rates'],gpy['new_shops']))
# Out:
# (0.21745133952877888, 0.3860647772115495)
# SpearmanrResult(correlation=0.18059855521155832, pvalue=0.4732892668249995)

# %% [markdown]
# although the number of new users and reviews increased every year the number of restaurants had a different effect of course because the number of restaurants was already high but there could be other reasons.

# %%
#reopen the file
datas=pd.read_json('yelp_academic_dataset_business.json', lines=True)
datas=datas.drop(['name','address','postal_code','latitude','longitude','stars','attributes','categories','hours'],axis=1)
datas
# Out:
#                    business_id               city state  review_count  is_open
# 0       6iYb2HFDywm3zjuRg0shjw            Boulder    CO            86        1
# 1       tCbdrRPZA0oiIYSmHG3J0w           Portland    OR           126        1
# 2       bvN78flM8NLprQ1a1y5dRg           Portland    OR            13        1
# 3       oaepsyvc0J17qwi8cfrOWg        Orange City    FL             8        1
# 4       PE9uqAjdw0E4-8mjGl3wVA            Atlanta    GA            14        1
# ...                        ...                ...   ...           ...      ...
# 160580  D2mHoIDXx9N8mS1pGoKV9Q             Austin    TX             8        1
# 160581  bQX-kwVTyZgcdZGEPzce6Q            Orlando    FL            18        1
# 160582  wvFZ06nmPmQ2-IVoPqVYLA            Orlando    FL             8        0
# 160583  GB75wPibj3IjNauaoCxyGA           Portland    OR            10        1
# 160584  ngmLL5Y5OT-bYHKU0kKrYA  Altamonte Springs    FL            82        0
#
# [160585 rows x 5 columns]

# %%
len(datas['state'].unique())
# Out:
# 31

# %%
states=datas.groupby(by='state')['business_id'].count().to_frame().reset_index()
states
# Out:
#    state  business_id
# 0    ABE            1
# 1     AL            1
# 2     AZ            2
# 3     BC        17298
# 4     CA           13
# 5     CO         3198
# 6     DC            1
# 7     DE            1
# 8     FL        21907
# 9     GA        18090
# 10    HI            1
# 11    IL            1
# 12    KS            1
# 13    KY            1
# 14    MA        36012
# 15    ME            1
# 16    MI            1
# 17    MN            1
# 18    NC            1
# 19    NH            4
# 20    NM            1
# 21    NY            2
# 22    OH        11258
# 23    OK            1
# 24    ON            2
# 25    OR        25175
# 26    TX        24485
# 27    VA            2
# 28    WA         3121
# 29    WI            1
# 30    WY            1

# %%
#now we plot the distribution
fig, ax=plt.subplots(1,1,figsize=(20,10))
ax.set_yscale('log')
sns.barplot(data=states,x='state',y='business_id',palette='colorblind',ax=ax)
plt.ylabel('number_of_activities')
plt.show()

# %% [markdown]
# it is now clear that many states have few restaurants and consequently we focus more on the states that are more relevants for our studies

# %%
rel_states=states[states['business_id']>100]
rel_states=rel_states.rename(columns={'business_id':'num_rest'})
rel_states
# Out:
#    state  num_rest
# 3     BC     17298
# 5     CO      3198
# 8     FL     21907
# 9     GA     18090
# 14    MA     36012
# 22    OH     11258
# 25    OR     25175
# 26    TX     24485
# 28    WA      3121

# %%
len(real_merge)-len(pd.merge(real_merge,rel_states))
#with this calculus we also notice that in this states the number of reviews is really small which means that in this
#states is actually useless make any studies
# Out:
# 741

# %%
#additionally we see how many 
real_merge.groupby(by='user_id').count()
#the total number of users is approximately 2000000 now we see how many users are present in the useless states
# Out:
#                         business_id  city  state  is_open  real_count  rates  \
# user_id
# ---2PmXbF47D870stH1jqA            3     3      3        3           3      3
# ---7FS-3SMy-cnnIPHcW9w            1     1      1        1           1      1
# ---fQxo-9tYZAkyWYrSfdA            1     1      1        1           1      1
# ---r2Fuca3t1PT3oalARQQ            1     1      1        1           1      1
# ---sEqd6eCGsnr8nOXrkDw            1     1      1        1           1      1
# ...                             ...   ...    ...      ...         ...    ...
# zzzPq8j7z2qR1oYqQTJxUg            1     1      1        1           1      1
# zzz_yXv7Z_JRT3tQmEo5rw            1     1      1        1           1      1
# zzzcuxFaP_FvdIB-fbP9iA            1     1      1        1           1      1
# zzzl5-rnSu3jclcANGsLgg            1     1      1        1           1      1
# zzzqnB-6DlYUbqAPxUxg4A            1     1      1        1           1      1
#
#                         useful  dates
# user_id
# ---2PmXbF47D870stH1jqA       3      3
# ---7FS-3SMy-cnnIPHcW9w       1      1
# ---fQxo-9tYZAkyWYrSfdA       1      1
# ---r2Fuca3t1PT3oalARQQ       1      1
# ---sEqd6eCGsnr8nOXrkDw       1      1
# ...                        ...    ...
# zzzPq8j7z2qR1oYqQTJxUg       1      1
# zzz_yXv7Z_JRT3tQmEo5rw       1      1
# zzzcuxFaP_FvdIB-fbP9iA       1      1
# zzzl5-rnSu3jclcANGsLgg       1      1
# zzzqnB-6DlYUbqAPxUxg4A       1      1
#
# [2189457 rows x 8 columns]

# %%
irr_states=states[states['business_id']<100]
irr_states=irr_states.rename(columns={'business_id':'num_rest'})
irr_merge=pd.merge(real_merge,irr_states)
irr_merge
# Out:
#                 business_id       city state  is_open  real_count  \
# 0    hWRZaOk4JWUPFhcomdOLwA  Ellsworth    KS        1          29
# 1    hWRZaOk4JWUPFhcomdOLwA  Ellsworth    KS        1          29
# 2    hWRZaOk4JWUPFhcomdOLwA  Ellsworth    KS        1          29
# 3    hWRZaOk4JWUPFhcomdOLwA  Ellsworth    KS        1          29
# 4    hWRZaOk4JWUPFhcomdOLwA  Ellsworth    KS        1          29
# ..                      ...        ...   ...      ...         ...
# 736  ph_XqC65-yx8wnOiFQWbYA   Portland    HI        1           7
# 737  ph_XqC65-yx8wnOiFQWbYA   Portland    HI        1           7
# 738  ph_XqC65-yx8wnOiFQWbYA   Portland    HI        1           7
# 739  ph_XqC65-yx8wnOiFQWbYA   Portland    HI        1           7
# 740  ph_XqC65-yx8wnOiFQWbYA   Portland    HI        1           7
#
#                     user_id  rates  useful dates  num_rest
# 0    TrpuFcWKpIQ9tjLAD8i5mg      1       0  2018         1
# 1    kUX-uFOTuJUXg_SRP6AqCA      1       0  2016         1
# 2    QLVGH-HPV8f-j0PDkWIJDw      1       0  2017         1
# 3    hNMTw0tnekjo-BGtZAh0lA      2       0  2014         1
# 4    4udmIHGerv9VP0fkuS4U-g      5       0  2018         1
# ..                      ...    ...     ...   ...       ...
# 736  y_1G1Dk5KyEG4GkeUm6idA      5       1  2019         1
# 737  zDYHp9NiTZxXjDkNS-OHaw      5       0  2019         1
# 738  JtHVvd-W883h8Uf7v-uC1Q      5       0  2019         1
# 739  iZoaRbiUMhydSHiynJ1ECA      5       0  2019         1
# 740  dL2ICqB8DUkGEEfsaxUWuA      5       1  2019         1
#
# [741 rows x 10 columns]

# %%
len(irr_merge['user_id'].unique())
# Out:
# 719

# %% [markdown]
# from this analysis is clear that there is no reason to keep these states

# %%
real_states=pd.merge(real_merge,rel_states)
real_states
# Out:
#                     business_id       city state  is_open  real_count  \
# 0        6iYb2HFDywm3zjuRg0shjw    Boulder    CO        1          86
# 1        6iYb2HFDywm3zjuRg0shjw    Boulder    CO        1          86
# 2        6iYb2HFDywm3zjuRg0shjw    Boulder    CO        1          86
# 3        6iYb2HFDywm3zjuRg0shjw    Boulder    CO        1          86
# 4        6iYb2HFDywm3zjuRg0shjw    Boulder    CO        1          86
# ...                         ...        ...   ...      ...         ...
# 8634657  1CHPSnEh4axD10HCqe8k-A  Vancouver    WA        0           7
# 8634658  1CHPSnEh4axD10HCqe8k-A  Vancouver    WA        0           7
# 8634659  1CHPSnEh4axD10HCqe8k-A  Vancouver    WA        0           7
# 8634660  1CHPSnEh4axD10HCqe8k-A  Vancouver    WA        0           7
# 8634661  1CHPSnEh4axD10HCqe8k-A  Vancouver    WA        0           7
#
#                         user_id  rates  useful dates  num_rest
# 0        93z0yh-sUpGZS-cSKu6xxA      5       1  2018      3198
# 1        Q_CZIvnsDHjpls-EPzzG7Q      2       0  2018      3198
# 2        rqxTSFFj5fZNmabY1fmTlw      5       0  2018      3198
# 3        vNPxlt5f50q0e2nVAScW3Q      4       0  2018      3198
# 4        eXRC79iX60xwA1UuGRuWNg      4       0  2018      3198
# ...                         ...    ...     ...   ...       ...
# 8634657  9kb3j5CuU1zTOHcZ9WlKNg      5       2  2008      3121
# 8634658  wofuEloxRTLYt35HHz3ZcQ      2       1  2010      3121
# 8634659  mxgEyquTYySQp0e1MlPOqA      1       1  2007      3121
# 8634660  WqHiC8Tbs_AnVoCUiDYcUA      5       2  2009      3121
# 8634661  0A64wqWs79WOaI79BhYULw      4       1  2007      3121
#
# [8634662 rows x 10 columns]

# %% [markdown]
# now the goal will be to understand which are the states with more reviews for the open activities

# %%
fig, ax=plt.subplots(1,1,figsize=(20,10))
#ax.set_yscale('log')
sns.countplot(data=real_states,x='state',palette='colorblind',ax=ax,hue='is_open')
plt.ylabel('number_of_reviews')
plt.show()

# %% [markdown]
# and we compare them with a barplot where we show the number of activities just to see which are the states with more active shops.

# %%
new_datas=pd.merge(datas, rel_states)
new_datas
# Out:
#                    business_id       city state  review_count  is_open  \
# 0       6iYb2HFDywm3zjuRg0shjw    Boulder    CO            86        1
# 1       rYs_1pNB_RMtn5WQh55QDA    Boulder    CO             5        1
# 2       Of6xu3pY3eHe2yhiyz2dvg    Boulder    CO            44        1
# 3       QkLMGBIP5Pp040l0Y9L0iA    Boulder    CO            13        0
# 4       _8Hejg5Q-_izIhLvq2ocnw    Boulder    CO           220        1
# ...                        ...        ...   ...           ...      ...
# 160539  93oKJR0k_ySx4p3u1z7IpA  Vancouver    WA            17        1
# 160540  hdAhDuyrPQ_Ufygm9nQxZw  Vancouver    WA            74        1
# 160541  jrI3lt2WRTDCijNdDClE5g  Vancouver    WA            19        1
# 160542  EPWCqcnk9x83axyYDWSHdg  Vancouver    WA            36        1
# 160543  1CHPSnEh4axD10HCqe8k-A  Vancouver    WA             7        0
#
#         num_rest
# 0           3198
# 1           3198
# 2           3198
# 3           3198
# 4           3198
# ...          ...
# 160539      3121
# 160540      3121
# 160541      3121
# 160542      3121
# 160543      3121
#
# [160544 rows x 6 columns]

# %%
fig, ax=plt.subplots(1,1,figsize=(20,10))
#ax.set_yscale('log')
sns.countplot(data=new_datas,x='state',palette='colorblind',ax=ax,hue='is_open')
plt.ylabel('number_of_activities')
plt.show()

# %% [markdown]
# from this first rough analysis we notice that BC and CH have a quite big number of activities but a small number of reviews compared to other states which could mean that in this states the number of activities using Yelp have increased more in this states than in others or otherwise that there are less people who use Yelp.

# %% [markdown]
# now we approach the 'space' data in another way, not considering states but considering cities, where we want to find the city with more users, the city with more reviews (which should be the same) and finally the city with a bigger rate reviews per user which could be actually the city where Yelp has become more popular

# %%
num_pers=real_states.groupby(by=['state','city','user_id'])['rates'].count()
num_pers=num_pers.to_frame().reset_index()
num_pers['city']=num_pers['city'].str.lower()
num_pers
# Out:
#         state       city                 user_id  rates
# 0          BC     anmore  -DFCC64NXgqrxlO8aLU5rg      1
# 1          BC     anmore  1mEXCefjMvMlEN3gykVmPw      2
# 2          BC     anmore  23wNTRDtDy0WhXrjTwwqew      1
# 3          BC     anmore  394T0WscQm_gODuiE5-P4g      1
# 4          BC     anmore  4oHg3hjxvHgg0N93J9lvGg      1
# ...       ...        ...                     ...    ...
# 3492319    WA  vanvouver  yp9g_NajZvf82hX9RtMUfg      1
# 3492320    WA  vanvouver  zDyG7rGuF7lwjTi3mzoD_A      1
# 3492321    WA  vanvouver  zTemdQsBRQWCgnCaWUTmgQ      1
# 3492322    WA  vanvouver  zUZvHc_vYIBZ2WZ6Mf8nwA      1
# 3492323    WA  vanvouver  zle1a07Qfy-NVwIGrsIXLg      1
#
# [3492324 rows x 4 columns]

# %%
num_pers_city=num_pers.groupby(by=['city','state'])['user_id'].count().to_frame().reset_index()
num_pers_city
# Out:
#                            city state  user_id
# 0    51 richard beall hwy 17-92    FL       11
# 1                       acworth    GA       14
# 2                       alafaya    FL      148
# 3              alamonte springs    FL      117
# 4                       allston    MA    24250
# ..                          ...   ...      ...
# 720                   woodstock    GA       10
# 721                   worcester    MA        8
# 722                 worthington    OH     4583
# 723                    wrenthan    MA       11
# 724                    zellwood    FL       37
#
# [725 rows x 3 columns]

# %%
num_pers_city=num_pers_city[num_pers_city['user_id']>30000]
num_pers_city['city'][num_pers_city['state']=='WA']='vancouverWA'
num_pers_city
# Out:
# <ipython-input-82-2b0b4c36495c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_pers_city['city'][num_pers_city['state']=='WA']='vancouverWA'
#                  city state  user_id
# 31            atlanta    GA   288036
# 40             austin    TX   382881
# 59          beaverton    OR    54138
# 83             boston    MA   273218
# 89            boulder    CO    52967
# 102         brookline    MA    36481
# 116         cambridge    MA    89475
# 154          columbus    OH    88307
# 179           decatur    GA    34932
# 321         kissimmee    FL    48115
# 331  lake buena vista    FL    30438
# 497           orlando    FL   262330
# 535          portland    OR   330662
# 596        somerville    MA    50390
# 647         vancouver    BC   110116
# 649       vancouverWA    WA    47936
# 712       winter park    FL    36012

# %%
fig, ax=plt.subplots(1,1,figsize=(20,10))
#ax.set_yscale('log')
sns.barplot(data=num_pers_city,x='city',y='user_id',palette='colorblind',ax=ax)
plt.ylabel('number_of_users')
plt.show()

# %% [markdown]
# the city with more users is Austin now if we count the number of reviews for this city we expect that it is also the city with most reviews

# %%
num_rates_city=num_pers.groupby(by=['city','state'])['rates'].sum().to_frame().reset_index()
num_rates_city
# Out:
#                            city state  rates
# 0    51 richard beall hwy 17-92    FL     11
# 1                       acworth    GA     14
# 2                       alafaya    FL    157
# 3              alamonte springs    FL    121
# 4                       allston    MA  42055
# ..                          ...   ...    ...
# 720                   woodstock    GA     10
# 721                   worcester    MA      8
# 722                 worthington    OH   6657
# 723                    wrenthan    MA     11
# 724                    zellwood    FL     39
#
# [725 rows x 3 columns]

# %%
num_rates_city=num_rates_city[num_rates_city['rates']>50000]
num_rates_city['city'][num_rates_city['state']=='WA']='vancouverWA'
num_rates_city
# Out:
# <ipython-input-87-a356566f1a53>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_rates_city['city'][num_rates_city['state']=='WA']='vancouverWA'
#             city state    rates
# 31       atlanta    GA   868698
# 40        austin    TX  1425981
# 59     beaverton    OR   116469
# 83        boston    MA   755408
# 89       boulder    CO   117610
# 102    brookline    MA    69451
# 116    cambridge    MA   224330
# 154     columbus    OH   291190
# 179      decatur    GA    70311
# 321    kissimmee    FL    73587
# 497      orlando    FL   669631
# 535     portland    OR  1146337
# 554     richmond    BC    57436
# 596   somerville    MA   106121
# 647    vancouver    BC   442566
# 649  vancouverWA    WA   115591
# 712  winter park    FL    75741

# %%
fig, ax=plt.subplots(1,1,figsize=(20,10))
#ax.set_yscale('log')
sns.barplot(data=num_rates_city,x='city',y='rates',palette='colorblind',ax=ax)
plt.ylabel('number_of_reviews')
plt.show()

# %% [markdown]
# as we expected the cities with a bigger number of users are also the cities with more reviews and also Austin is again the city with more reviews as we expected, now we want to find the city with highest rate review/user, to do so we merge the two dataset created for the plots

# %%
rate_per_city=pd.merge(num_rates_city, num_pers_city)
rate_per_city
# Out:
#            city state    rates  user_id
# 0       atlanta    GA   868698   288036
# 1        austin    TX  1425981   382881
# 2     beaverton    OR   116469    54138
# 3        boston    MA   755408   273218
# 4       boulder    CO   117610    52967
# 5     brookline    MA    69451    36481
# 6     cambridge    MA   224330    89475
# 7      columbus    OH   291190    88307
# 8       decatur    GA    70311    34932
# 9     kissimmee    FL    73587    48115
# 10      orlando    FL   669631   262330
# 11     portland    OR  1146337   330662
# 12   somerville    MA   106121    50390
# 13    vancouver    BC   442566   110116
# 14  vancouverWA    WA   115591    47936
# 15  winter park    FL    75741    36012

# %%
rate_per_city['num_rev_us']=rate_per_city['rates']/rate_per_city['user_id']
rate_per_city
# Out:
#            city state    rates  user_id  num_rev_us
# 0       atlanta    GA   868698   288036    3.015936
# 1        austin    TX  1425981   382881    3.724345
# 2     beaverton    OR   116469    54138    2.151335
# 3        boston    MA   755408   273218    2.764854
# 4       boulder    CO   117610    52967    2.220439
# 5     brookline    MA    69451    36481    1.903758
# 6     cambridge    MA   224330    89475    2.507181
# 7      columbus    OH   291190    88307    3.297474
# 8       decatur    GA    70311    34932    2.012796
# 9     kissimmee    FL    73587    48115    1.529398
# 10      orlando    FL   669631   262330    2.552628
# 11     portland    OR  1146337   330662    3.466794
# 12   somerville    MA   106121    50390    2.105993
# 13    vancouver    BC   442566   110116    4.019089
# 14  vancouverWA    WA   115591    47936    2.411361
# 15  winter park    FL    75741    36012    2.103216

# %%
fig, ax=plt.subplots(1,1,figsize=(20,10))
#ax.set_yscale('log')
sns.barplot(data=rate_per_city,x='city',y='num_rev_us',palette='colorblind',ax=ax)
plt.ylabel('number_of_reviews_per_user')
plt.show()

# %% [markdown]
# Because Austin is the city with the biggest number of review per user and also with the biggest number of users and of reviews is the city where Yelp is most used, although Austin is in TX and TX is not the state with the biggest number of reviews

# %% [markdown]
# So now we study the evolution of the number of users, reviews and restaurants of this city

# %%
Austin=real_states[real_states['city']=='Austin'][real_states['state']=='TX']
#Austin
Austin=Austin.sort_values(by='dates',ascending=True)
Austin
# Out:
# <ipython-input-92-cc08b389c87f>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Austin=real_states[real_states['city']=='Austin'][real_states['state']=='TX']
#                     business_id    city state  is_open  real_count  \
# 6167501  bUKDJu4OLYYvc1HV62dDbw  Austin    TX        1         334
# 6185339  h61urFQyb2JhVFOnkBGkDA  Austin    TX        1         253
# 6390472  4xg9_AMn-NpFfxVK4Al6aQ  Austin    TX        0          92
# 6094666  9VlV09HupfzZcRP3lTRi8Q  Austin    TX        0         390
# 5576674  4wRdoVx6KuZd2S4OZs4yJw  Austin    TX        1         176
# ...                         ...     ...   ...      ...         ...
# 5575999  f48kqEE2ceyhiB9OnY7_YQ  Austin    TX        1          42
# 5747827  JcSejr2IQdXtYOXt_PJceg  Austin    TX        1          40
# 6386791  Su_TBFW5kQGDM4Wzthu3Qw  Austin    TX        1         454
# 5576004  f48kqEE2ceyhiB9OnY7_YQ  Austin    TX        1          42
# 4973989  YZs1gNSh_sN8JmN_nrpxeA  Austin    TX        1        3603
#
#                         user_id  rates  useful dates  num_rest
# 6167501  VSbOAu9bmctgDe_HRiMgEA      3       1  2005     24485
# 6185339  J9b9YUP1bWSkO3T7XS6uYA      5       1  2005     24485
# 6390472  ctwwsl5_DSCzwPxtjzdl2A      5       3  2005     24485
# 6094666  VSbOAu9bmctgDe_HRiMgEA      3       2  2005     24485
# 5576674  VSbOAu9bmctgDe_HRiMgEA      4       1  2005     24485
# ...                         ...    ...     ...   ...       ...
# 5575999  BAUTyU3MqYEdYgjEhjt3OQ      5       1  2021     24485
# 5747827  _OdNQyST3eQ_vxvofb1NIw      3       0  2021     24485
# 6386791  n-QfBVtOCS96GzpqjvGvFw      5       7  2021     24485
# 5576004  IynOPHmdb78tq4pMUCypag      5       0  2021     24485
# 4973989  WL28N8LSxfhip8nZlrNwyw      5       0  2021     24485
#
# [1425160 rows x 10 columns]

# %%
Atlanta=real_states[real_states['city']=='Atlanta'][real_states['state']=='GA']
Atlanta=Atlanta.sort_values(by='dates',ascending=True)
Atlanta
# Out:
# <ipython-input-93-7217b0099b0a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Atlanta=real_states[real_states['city']=='Atlanta'][real_states['state']=='GA']
#                     business_id     city state  is_open  real_count  \
# 3566722  vOfvhKDThSknAe9IF-gI1g  Atlanta    GA        0           7
# 3170454  3ehyrexo3WcoTy74c2jDKA  Atlanta    GA        1        1615
# 3681956  4JI96FxgS4dVZ4yzk7kDnQ  Atlanta    GA        1          60
# 3670412  DWhMnby2t-z1EwCNKGqAqw  Atlanta    GA        1         559
# 3807398  C0iz_vMnCEqubIR-joXxPg  Atlanta    GA        1         111
# ...                         ...      ...   ...      ...         ...
# 3158646  AtkYjGhDBNX9YzL05mIEEA  Atlanta    GA        1          81
# 2732673  v7jxMevlILvPkDWubX_Xug  Atlanta    GA        1         506
# 3511391  LMJBhM_HGfFGJVwry3eC1g  Atlanta    GA        1         179
# 3648552  HZ4y1OEU7-1Y0y7CMdotLQ  Atlanta    GA        1         396
# 3157393  5Yf__1twcUqmvDgjD6CW8Q  Atlanta    GA        1          40
#
#                         user_id  rates  useful dates  num_rest
# 3566722  mo2g9qeh-dXqLh3PE9T4Pg      4       0  2004     18090
# 3170454  TDXV6AC5PYOZEyN9eeODfA      4       0  2005     18090
# 3681956  W-9Y-pzCgcCYkaGWf6FEdQ      5       1  2005     18090
# 3670412  Da_ZO8lKwIacljqKUJbAlw      5       0  2005     18090
# 3807398  Za18n8WOCWsgPkBcVlGwig      4       4  2005     18090
# ...                         ...    ...     ...   ...       ...
# 3158646  pa3D36unBCBYEgKDqdng3w      4       0  2021     18090
# 2732673  78p7enmswRD2crB_S-BzDA      1       0  2021     18090
# 3511391  iU9nBM9FGpjnHzzHDQmWrA      1       0  2021     18090
# 3648552  flc_fKo-zjk4GTZBePfsrQ      5       0  2021     18090
# 3157393  4NlzrMHt9SCW8pSnRPf8TA      4       0  2021     18090
#
# [868258 rows x 10 columns]

# %%
Portland=real_states[real_states['city']=='Portland'][real_states['state']=='OR']
Portland=Portland.sort_values(by='dates',ascending=True)
Portland
# Out:
# <ipython-input-94-685c7c127a26>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Portland=real_states[real_states['city']=='Portland'][real_states['state']=='OR']
#                     business_id      city state  is_open  real_count  \
# 771611   QYJ9lN_gDOwPsvUqfetoHQ  Portland    OR        1         204
# 734794   1EqU3wlAS1wgGQvYVl8UuQ  Portland    OR        1         422
# 474061   fsKFkh6_TBnhdTmXQuk-gg  Portland    OR        1        1208
# 1324503  ZUt1moXHsR4tDr2Iq61ZHQ  Portland    OR        1         310
# 712713   tUuVG-ZuPX-9jJWSft_wMg  Portland    OR        1         239
# ...                         ...       ...   ...      ...         ...
# 483551   mChvCuGO_RBy4kmGZLPikA  Portland    OR        1           5
# 337683   voCBS1W9DysckP0J8H31AA  Portland    OR        1         133
# 407120   EL-XbjCT3ElNLNTdmhDG4A  Portland    OR        1         377
# 1471841  zPPmz4fc9z0fuXY5Nb0EiQ  Portland    OR        1         261
# 1587391  GB75wPibj3IjNauaoCxyGA  Portland    OR        1          10
#
#                         user_id  rates  useful dates  num_rest
# 771611   Y8mjo9ne1RG8Tz-7j1tjzw      5       0  2004     25175
# 734794   ptLc4l0wjx_q5OrOjSAhog      3       0  2005     25175
# 474061   ctwwsl5_DSCzwPxtjzdl2A      3       1  2005     25175
# 1324503  gkJymaEZE6O52NSzQuKVyg      3       0  2005     25175
# 712713   aJSvH7eBn9DJYw5i9Le8aA      4       1  2005     25175
# ...                         ...    ...     ...   ...       ...
# 483551   DWWbNItPcqXrJ7qSoo2ISQ      1       0  2021     25175
# 337683   1d8qup6duQ4LJToD-t-GEg      5       0  2021     25175
# 407120   bsLAawJLdm_bmwjInlgGIQ      5       0  2021     25175
# 1471841  9OULHH_uuum2Me34mS1c4A      5       0  2021     25175
# 1587391  oHqPHNMtQwbA-JVF5gccUg      2       0  2021     25175
#
# [1145530 rows x 10 columns]

# %%
fig, ax=plt.subplots(3,1,figsize=(10,10), sharey=True)
#ax.set_yscale('log')
sns.countplot(data=Austin,x='dates',palette='colorblind',ax=ax[0])
ax[0].set_ylabel('number_of_reviews')
ax[0].set_xlabel('')
ax[0].set_title('Austin')
sns.countplot(data=Atlanta,x='dates',palette='colorblind',ax=ax[1])
ax[1].set_ylabel('number_of_reviews')
ax[1].set_xlabel('')
ax[1].set_title('Atlanta')
sns.countplot(data=Portland,x='dates',palette='colorblind',ax=ax[2])
ax[2].set_ylabel('number_of_reviews')
ax[2].set_title('Portland')
plt.show()

# %% [markdown]
# from this firts plot we notice that the city has entered in Yelp app one year after its creation and that we have its peak in 2018 (we don't consider 2020 and 2021 because of covid), anyway in the last years it was really used.
